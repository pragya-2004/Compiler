# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.2-py3-none-any.whl.metadata (9.4 kB)
# Downloading pyspellchecker-0.8.2-py3-none-any.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 91.4 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.2

# %%
from spellchecker import SpellChecker

# %%
# READING GRAMMAR SPECIFICATIONS

inputFile = open('grammar.txt', 'r')
inputText = inputFile.read()
grammarRules = [ rule.strip() for rule in inputText.split("\n")]
grammarRules
# Out:
# ['S -> NP_SG PAST S1 | NP_SG PAST_PERFECT S1 | NP_SG PAST_CONT_SG S1 | NP_SG PAST_PERFECT_CONT S1 | NP_SG PRES_SG S1 | NP_SG PRES_PERFECT_SG S1 | NP_SG PRES_CONT_SG S1 | NP_SG PRES_PERFECT_CONT_SG S1 | NP_SG FUTURE S1 | NP_SG FUTURE_PERFECT S1 | NP_SG FUTURE_CONT S1 | NP_SG FUTURE_PERFECT_CONT S1 | NP_PL PAST S1 | NP_PL PAST_PERFECT S1 | NP_PL PAST_CONT_PL S1 | NP_PL PAST_PERFECT_CONT S1 | NP_PL PRES_PL S1  | NP_PL PRES_PERFECT_PL S1 | NP_PL PRES_CONT_PL S1 | NP_PL PRES_PERFECT_CONT_PL S1 | NP_PL FUTURE S1 | NP_PL FUTURE_PERFECT S1 | NP_PL FUTURE_CONT S1 | NP_PL FUTURE_PERFECT_CONT S1 | S ADV',
#  'S1 -> NP | ADV',
#  'NP -> NP_SG | NP_PL | PP | NP PP',
#  'NP_SG ->  PRONOUN_SG | PRONOUN_SG NOM_SG| PROPERNOUN | NOM_SG | DET_SG NOM_SG | DET_BOTH NOM_SG | ADV NP_SG | NP_SG CONJ NP',
#  'NOM_SG -> NOUN_SG | ADJ NOUN_SG | NOM_SG NOUN_SG',
#  'NP_PL -> PRONOUN_PL | PRONOUN_PL NOM_PL| NOM_PL | DET_PL NOM_PL | DET_BOTH NOM_PL | ADV NP_PL | NP_PL CONJ NP',
#  'NOM_PL -> NOUN_PL | ADJ NOUN_PL | NOM_PL NOUN_PL',
#  'PP -> PREPOS NP_SG | PREPOS NP_PL',
#  'PAST -> V2 | ADV V2',
#  'PAST_PERFECT -> had V3 | had ADV V3',
#  'PAST_CONT_SG -> was GERUNDV | was ADV GERUNDV',
#  'PAST_CONT_PL -> were GERUNDV | were ADV GERUNDV',
#  'PAST_PERFECT_CONT -> had been GERUNDV | had ADV been GERUNDV',
#  'PRES_SG -> V1_SG | ADV V1_SG',
#  'PRES_PL -> V1_PL | ADV V1_PL',
#  'PRES_PERFECT_SG -> has V3 | has ADV V3',
#  'PRES_PERFECT_PL -> have V3 | have ADV V3',
#  'PRES_CONT_SG -> is GERUNDV | is ADV GERUNDV',
#  'PRES_CONT_PL -> are GERUNDV | are ADV GERUNDV',
#  'PRES_PERFECT_CONT_SG -> has been GERUNDV | has ADV been GERUNDV | has been | has ADV been',
#  'PRES_PERFECT_CONT_PL -> have been GERUNDV | have ADV been GERUNDV',
#  'FUTURE -> will V1_PL | will ADV V1_PL',
#  'FUTURE_PERFECT -> will have V3 | will have ADV V3',
#  'FUTURE_CONT -> will be GERUNDV | will ADV be GERUNDV',
#  'FUTURE_PERFECT_CONT -> will have been GERUNDV | will have ADV been GERUNDV',
#  'PRONOUN_SG -> my | she | he | it | him | i | her | his',
#  'PRONOUN_PL -> they | us | you | we | their',
#  'RELPR_SG -> which',
#  'RELPR_PL -> whom',
#  'PROPERNOUN -> ishwarya | joseph | india | germany | ajitesh | navvya | ritheesh | switzerland | paris | wednesday | january | may | turkey | easter | november | raj | canada | america | john',
#  'NOUN_SG -> sentence | me | kabaddi | friend | patient | parcel | player | moment | morning | grandfather | outlet | evening | programming | building | thinking | mom | weekend | brother | basketball | afternoon | book | accountant | milk | accident | neighbourhood | car | phone | night | airplane | fog | street | dad | bed | fire | house | zoo | cold | pope | cup | sister | party | tea | weather | call | baby | movie | picture | pilot | airport | assignment | week | month | room | homework | husband | year | school | teacher | letter | football | food | mountain | wife | topper | song | show | garden | album',
#  'NOUN_PL -> roses | mountains | goats | films | times | emails | people | children |  specialists | girls | parents | jacksons | cows | boys | books | years | portraits | friends | ages | weeks | letters | peacocks | books',
#  'DET_SG -> a | an | this | that',
#  'DET_PL -> these | all | many | no',
#  'DET_BOTH -> the',
#  'CONJ -> and | but | because | while',
#  'ADJ -> red | delicious | first | few | two | four | three | fun | since | sweet | nice | severe | terrible | hungry | new | whole | last | every | critical',
#  'ADV -> well | gracefully | before | next | very | when | not | whereabouts | constantly | lately | yesterday | ago | tomorrow | early | still | twice | always | already | past | never | today | never | recently | heavily',
#  'PREPOS -> at | in | of | for | by | from | far | on | around | as | to | down',
#  'V1_SG -> climbs | teaches | plays | cooks | is | likes | be | know | am | draws | works | understands | invloves | sings',
#  'V1_PL -> teach | are | sing | give | think | rain | turn | go | see | do | take | study | speak | drink | cook | meet',
#  'GERUNDV -> teaching | running | writing | opening | burning | feeling | enjoying | living | spending | ringing | repairing | visiting | having | climbing | getting | meeting | playing | cleaning | going | looking | suffering | raining | waiting | studying | snowing | seeing | dating | taking | listening | dancing',
#  'V2 -> taught | were | was | went | knew | would | started | received | gave | caught | married | understood | flew | drink | read | made | tired | saw | did',
#  'V3 -> seen | written | given | done | gone | made | flown | painted | fed | met | finished | acted | watched']

# %%
class Grammar :
  def __init__(self, grammarStr) :
    self.input = grammarStr
    self.symbols = set()
    self.terminals = set()
    self.nonterminals = set()
    self.startSymbol = None
    self.grammar = {}

    for production in grammarStr :
      # The partition() method searches for a specified string, and splits the string into a tuple containing three elements.
      head, _, bodies = production.partition(' -> ')

      # The nonterminal of the first production is considered to be the start symbol
      if self.startSymbol is None :
        self.startSymbol = head

      self.grammar.setdefault(head, set())
      self.nonterminals.add(head)

      bodies = {tuple(body.strip().split(" ")) for body in ' '.join(bodies.split(" ")).split('|') }

      for body in bodies :
        self.grammar[head].add(body)
        for symbol in body :
          if symbol.isupper() :
            self.nonterminals.add(symbol)
          else :
            self.terminals.add(symbol)

    self.symbols = self.nonterminals | self.terminals

  def __str__ (self) :
    print("Start Symbol : " , self.startSymbol)
    print("Non-terminals : " , self.nonterminals)
    print("Terminals : " , self.terminals)
    print("Productions : ")
    for head in self.grammar :
      for body in self.grammar[head] :
        print(head, "->", body)
    return ""

# %%
G = Grammar(grammarRules)
print(G)
properNouns = set()
for pn in G.grammar["PROPERNOUN"]:
  for noun in pn :
    properNouns.add(noun)
# Out:
# Start Symbol :  S
# Non-terminals :  {'NP_PL', 'S1', 'V2', 'PRES_SG', 'PP', 'S', 'FUTURE_PERFECT_CONT', 'PAST_CONT_SG', 'PAST_PERFECT_CONT', 'PRES_PL', 'ADV', 'PRES_PERFECT_SG', 'NOM_SG', 'NOUN_SG', 'PRES_PERFECT_CONT_PL', 'PREPOS', 'GERUNDV', 'DET_BOTH', 'PAST_CONT_PL', 'FUTURE_CONT', 'NOUN_PL', 'ADJ', 'V1_PL', 'FUTURE_PERFECT', 'PAST_PERFECT', 'NOM_PL', 'PAST', 'PRES_PERFECT_PL', 'NP', 'PROPERNOUN', 'PRES_CONT_PL', 'CONJ', 'V1_SG', 'FUTURE', 'PRONOUN_PL', 'PRES_CONT_SG', 'RELPR_SG', 'DET_SG', 'RELPR_PL', 'NP_SG', 'V3', 'PRONOUN_SG', 'PRES_PERFECT_CONT_SG', 'DET_PL'}
# Terminals :  {'programming', 'call', 'room', 'weekend', 'to', 'draws', 'patient', 'rain', 'flown', 'done', 'already', 'whereabouts', 'america', 'mom', 'nice', 'far', 'evening', 'boys', 'and', 'know', 'recently', 'garden', 'repairing', 'flew', 'pope', 'seen', 'cook', 'germany', 'tomorrow', 'waiting', 'morning', 'sweet', 'new', 'are', 'is', 'football', 'early', 'sings', 'us', 'dancing', 'week', 'would', 'cup', 'fed', 'because', 'suffering', 'climbing', 'jacksons', 'album', 'show', 'parcel', 'not', 'bed', 'these', 'had', 'around', 'dating', 'him', 'thinking', 'see', 'a', 'think', 'terrible', 'neighbourhood', 'switzerland', 'feeling', 'afternoon', 'written', 'past', 'first', 'books', 'she', 'as', 'on', 'turkey', 'night', 'that', 'yesterday', 'give', 'gave', 'invloves', 'john', 'january', 'next', 'letter', 'down', 'am', 'climbs', 'accountant', 'raining', 'husband', 'be', 'year', 'getting', 'have', 'sing', 'very', 'lately', 'month', 'teacher', 'playing', 'heavily', 'drink', 'living', 'house', 'received', 'weeks', 'tired', 'assignment', 'meet', 'sentence', 'raj', 'severe', 'car', 'caught', 'this', 'many', 'was', 'peacocks', 'running', 'hungry', 'go', 'grandfather', 'watched', 'people', 'at', 'last', 'years', 'ritheesh', 'before', 'been', 'we', 'outlet', 'whole', 'ishwarya', 'wife', 'for', 'two', 'baby', 'enjoying', 'ajitesh', 'take', 'school', 'well', 'ages', 'visiting', 'specialists', 'of', 'gracefully', 'three', 'from', 'every', 'were', 'while', 'when', 'turn', 'milk', 'painted', 'tea', 'snowing', 'mountains', 'cleaning', 'meeting', 'likes', 'writing', 'acted', 'zoo', 'airplane', 'picture', 'few', 'it', 'constantly', 'teaching', 'married', 'critical', 'basketball', 'burning', 'movie', 'parents', 'red', 'never', 'saw', 'canada', 'went', 'his', 'studying', 'song', 'he', 'friend', 'listening', 'twice', 'airport', 'wednesday', 'india', 'an', 'their', 'her', 'fun', 'given', 'since', 'still', 'plays', 'fire', 'films', 'pilot', 'the', 'kabaddi', 'ago', 'you', 'all', 'cold', 'read', 'cooks', 'did', 'seeing', 'sister', 'cows', 'i', 'four', 'teach', 'spending', 'navvya', 'times', 'understood', 'goats', 'always', 'do', 'homework', 'will', 'emails', 'understands', 'by', 'topper', 'no', 'today', 'moment', 'building', 'gone', 'phone', 'having', 'food', 'has', 'november', 'taking', 'ringing', 'easter', 'in', 'finished', 'study', 'joseph', 'letters', 'accident', 'they', 'knew', 'children', 'started', 'fog', 'weather', 'friends', 'book', 'but', 'works', 'made', 'roses', 'player', 'may', 'taught', 'met', 'mountain', 'delicious', 'opening', 'party', 'street', 'dad', 'girls', 'looking', 'me', 'whom', 'speak', 'brother', 'portraits', 'paris', 'going', 'which', 'teaches', 'my'}
# Productions :
# S -> ('NP_PL', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_PL', 'PAST_PERFECT', 'S1')
# S -> ('NP_SG', 'PAST_CONT_SG', 'S1')
# S -> ('NP_PL', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'PRES_CONT_SG', 'S1')
# S -> ('NP_PL', 'PRES_PL', 'S1')
# S -> ('NP_SG', 'FUTURE', 'S1')
# S -> ('NP_PL', 'PRES_CONT_PL', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT', 'S1')
# S -> ('NP_PL', 'PAST_CONT_PL', 'S1')
# S -> ('NP_PL', 'PAST', 'S1')
# S -> ('NP_PL', 'FUTURE_CONT', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_SG', 'S1')
# S -> ('NP_SG', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_PL', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_PL', 'FUTURE', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_CONT_PL', 'S1')
# S -> ('S', 'ADV')
# S -> ('NP_SG', 'FUTURE_PERFECT', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_CONT_SG', 'S1')
# S -> ('NP_SG', 'PAST', 'S1')
# S -> ('NP_SG', 'PRES_SG', 'S1')
# S -> ('NP_SG', 'FUTURE_CONT', 'S1')
# S1 -> ('ADV',)
# S1 -> ('NP',)
# NP -> ('PP',)
# NP -> ('NP_SG',)
# NP -> ('NP', 'PP')
# NP -> ('NP_PL',)
# NP_SG -> ('ADV', 'NP_SG')
# NP_SG -> ('PRONOUN_SG', 'NOM_SG')
# NP_SG -> ('NOM_SG',)
# NP_SG -> ('DET_BOTH', 'NOM_SG')
# NP_SG -> ('DET_SG', 'NOM_SG')
# NP_SG -> ('PRONOUN_SG',)
# NP_SG -> ('PROPERNOUN',)
# NP_SG -> ('NP_SG', 'CONJ', 'NP')
# NOM_SG -> ('NOUN_SG',)
# NOM_SG -> ('NOM_SG', 'NOUN_SG')
# NOM_SG -> ('ADJ', 'NOUN_SG')
# NP_PL -> ('DET_PL', 'NOM_PL')
# NP_PL -> ('ADV', 'NP_PL')
# NP_PL -> ('NP_PL', 'CONJ', 'NP')
# NP_PL -> ('PRONOUN_PL', 'NOM_PL')
# NP_PL -> ('PRONOUN_PL',)
# NP_PL -> ('NOM_PL',)
# NP_PL -> ('DET_BOTH', 'NOM_PL')
# NOM_PL -> ('NOUN_PL',)
# NOM_PL -> ('NOM_PL', 'NOUN_PL')
# NOM_PL -> ('ADJ', 'NOUN_PL')
# PP -> ('PREPOS', 'NP_SG')
# PP -> ('PREPOS', 'NP_PL')
# PAST -> ('ADV', 'V2')
# PAST -> ('V2',)
# PAST_PERFECT -> ('had', 'ADV', 'V3')
# PAST_PERFECT -> ('had', 'V3')
# PAST_CONT_SG -> ('was', 'ADV', 'GERUNDV')
# PAST_CONT_SG -> ('was', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'ADV', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'ADV', 'been', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'been', 'GERUNDV')
# PRES_SG -> ('ADV', 'V1_SG')
# PRES_SG -> ('V1_SG',)
# PRES_PL -> ('ADV', 'V1_PL')
# PRES_PL -> ('V1_PL',)
# PRES_PERFECT_SG -> ('has', 'ADV', 'V3')
# PRES_PERFECT_SG -> ('has', 'V3')
# PRES_PERFECT_PL -> ('have', 'V3')
# PRES_PERFECT_PL -> ('have', 'ADV', 'V3')
# PRES_CONT_SG -> ('is', 'GERUNDV')
# PRES_CONT_SG -> ('is', 'ADV', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'ADV', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been')
# PRES_PERFECT_CONT_SG -> ('has', 'been')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_PL -> ('have', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_PL -> ('have', 'ADV', 'been', 'GERUNDV')
# FUTURE -> ('will', 'V1_PL')
# FUTURE -> ('will', 'ADV', 'V1_PL')
# FUTURE_PERFECT -> ('will', 'have', 'ADV', 'V3')
# FUTURE_PERFECT -> ('will', 'have', 'V3')
# FUTURE_CONT -> ('will', 'ADV', 'be', 'GERUNDV')
# FUTURE_CONT -> ('will', 'be', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'been', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'ADV', 'been', 'GERUNDV')
# PRONOUN_SG -> ('him',)
# PRONOUN_SG -> ('it',)
# PRONOUN_SG -> ('he',)
# PRONOUN_SG -> ('my',)
# PRONOUN_SG -> ('his',)
# PRONOUN_SG -> ('she',)
# PRONOUN_SG -> ('i',)
# PRONOUN_SG -> ('her',)
# PRONOUN_PL -> ('you',)
# PRONOUN_PL -> ('us',)
# PRONOUN_PL -> ('we',)
# PRONOUN_PL -> ('their',)
# PRONOUN_PL -> ('they',)
# RELPR_SG -> ('which',)
# RELPR_PL -> ('whom',)
# PROPERNOUN -> ('may',)
# PROPERNOUN -> ('easter',)
# PROPERNOUN -> ('january',)
# PROPERNOUN -> ('switzerland',)
# PROPERNOUN -> ('ajitesh',)
# PROPERNOUN -> ('germany',)
# PROPERNOUN -> ('wednesday',)
# PROPERNOUN -> ('joseph',)
# PROPERNOUN -> ('navvya',)
# PROPERNOUN -> ('november',)
# PROPERNOUN -> ('turkey',)
# PROPERNOUN -> ('ritheesh',)
# PROPERNOUN -> ('john',)
# PROPERNOUN -> ('ishwarya',)
# PROPERNOUN -> ('america',)
# PROPERNOUN -> ('canada',)
# PROPERNOUN -> ('paris',)
# PROPERNOUN -> ('raj',)
# PROPERNOUN -> ('india',)
# NOUN_SG -> ('picture',)
# NOUN_SG -> ('school',)
# NOUN_SG -> ('moment',)
# NOUN_SG -> ('food',)
# NOUN_SG -> ('outlet',)
# NOUN_SG -> ('brother',)
# NOUN_SG -> ('car',)
# NOUN_SG -> ('room',)
# NOUN_SG -> ('month',)
# NOUN_SG -> ('cup',)
# NOUN_SG -> ('night',)
# NOUN_SG -> ('friend',)
# NOUN_SG -> ('patient',)
# NOUN_SG -> ('airport',)
# NOUN_SG -> ('basketball',)
# NOUN_SG -> ('pilot',)
# NOUN_SG -> ('airplane',)
# NOUN_SG -> ('garden',)
# NOUN_SG -> ('year',)
# NOUN_SG -> ('movie',)
# NOUN_SG -> ('pope',)
# NOUN_SG -> ('weather',)
# NOUN_SG -> ('show',)
# NOUN_SG -> ('kabaddi',)
# NOUN_SG -> ('sister',)
# NOUN_SG -> ('house',)
# NOUN_SG -> ('evening',)
# NOUN_SG -> ('mom',)
# NOUN_SG -> ('bed',)
# NOUN_SG -> ('book',)
# NOUN_SG -> ('mountain',)
# NOUN_SG -> ('tea',)
# NOUN_SG -> ('album',)
# NOUN_SG -> ('song',)
# NOUN_SG -> ('letter',)
# NOUN_SG -> ('me',)
# NOUN_SG -> ('street',)
# NOUN_SG -> ('phone',)
# NOUN_SG -> ('party',)
# NOUN_SG -> ('parcel',)
# NOUN_SG -> ('sentence',)
# NOUN_SG -> ('weekend',)
# NOUN_SG -> ('call',)
# NOUN_SG -> ('assignment',)
# NOUN_SG -> ('thinking',)
# NOUN_SG -> ('baby',)
# NOUN_SG -> ('husband',)
# NOUN_SG -> ('football',)
# NOUN_SG -> ('fire',)
# NOUN_SG -> ('dad',)
# NOUN_SG -> ('wife',)
# NOUN_SG -> ('grandfather',)
# NOUN_SG -> ('player',)
# NOUN_SG -> ('afternoon',)
# NOUN_SG -> ('programming',)
# NOUN_SG -> ('building',)
# NOUN_SG -> ('accident',)
# NOUN_SG -> ('cold',)
# NOUN_SG -> ('neighbourhood',)
# NOUN_SG -> ('topper',)
# NOUN_SG -> ('homework',)
# NOUN_SG -> ('week',)
# NOUN_SG -> ('teacher',)
# NOUN_SG -> ('morning',)
# NOUN_SG -> ('fog',)
# NOUN_SG -> ('zoo',)
# NOUN_SG -> ('milk',)
# NOUN_SG -> ('accountant',)
# NOUN_PL -> ('ages',)
# NOUN_PL -> ('mountains',)
# NOUN_PL -> ('emails',)
# NOUN_PL -> ('specialists',)
# NOUN_PL -> ('portraits',)
# NOUN_PL -> ('cows',)
# NOUN_PL -> ('girls',)
# NOUN_PL -> ('boys',)
# NOUN_PL -> ('years',)
# NOUN_PL -> ('friends',)
# NOUN_PL -> ('roses',)
# NOUN_PL -> ('weeks',)
# NOUN_PL -> ('films',)
# NOUN_PL -> ('parents',)
# NOUN_PL -> ('goats',)
# NOUN_PL -> ('letters',)
# NOUN_PL -> ('people',)
# NOUN_PL -> ('children',)
# NOUN_PL -> ('jacksons',)
# NOUN_PL -> ('times',)
# NOUN_PL -> ('books',)
# NOUN_PL -> ('peacocks',)
# DET_SG -> ('that',)
# DET_SG -> ('this',)
# DET_SG -> ('an',)
# DET_SG -> ('a',)
# DET_PL -> ('all',)
# DET_PL -> ('these',)
# DET_PL -> ('many',)
# DET_PL -> ('no',)
# DET_BOTH -> ('the',)
# CONJ -> ('and',)
# CONJ -> ('because',)
# CONJ -> ('but',)
# CONJ -> ('while',)
# ADJ -> ('nice',)
# ADJ -> ('new',)
# ADJ -> ('sweet',)
# ADJ -> ('since',)
# ADJ -> ('delicious',)
# ADJ -> ('hungry',)
# ADJ -> ('first',)
# ADJ -> ('critical',)
# ADJ -> ('every',)
# ADJ -> ('last',)
# ADJ -> ('whole',)
# ADJ -> ('red',)
# ADJ -> ('four',)
# ADJ -> ('fun',)
# ADJ -> ('two',)
# ADJ -> ('three',)
# ADJ -> ('severe',)
# ADJ -> ('few',)
# ADJ -> ('terrible',)
# ADV -> ('not',)
# ADV -> ('never',)
# ADV -> ('ago',)
# ADV -> ('well',)
# ADV -> ('today',)
# ADV -> ('gracefully',)
# ADV -> ('twice',)
# ADV -> ('early',)
# ADV -> ('yesterday',)
# ADV -> ('already',)
# ADV -> ('when',)
# ADV -> ('heavily',)
# ADV -> ('always',)
# ADV -> ('past',)
# ADV -> ('whereabouts',)
# ADV -> ('constantly',)
# ADV -> ('lately',)
# ADV -> ('tomorrow',)
# ADV -> ('still',)
# ADV -> ('very',)
# ADV -> ('next',)
# ADV -> ('recently',)
# ADV -> ('before',)
# PREPOS -> ('from',)
# PREPOS -> ('by',)
# PREPOS -> ('down',)
# PREPOS -> ('for',)
# PREPOS -> ('of',)
# PREPOS -> ('on',)
# PREPOS -> ('far',)
# PREPOS -> ('to',)
# PREPOS -> ('at',)
# PREPOS -> ('as',)
# PREPOS -> ('around',)
# PREPOS -> ('in',)
# V1_SG -> ('teaches',)
# V1_SG -> ('be',)
# V1_SG -> ('sings',)
# V1_SG -> ('invloves',)
# V1_SG -> ('cooks',)
# V1_SG -> ('likes',)
# V1_SG -> ('know',)
# V1_SG -> ('am',)
# V1_SG -> ('climbs',)
# V1_SG -> ('works',)
# V1_SG -> ('is',)
# V1_SG -> ('draws',)
# V1_SG -> ('understands',)
# V1_SG -> ('plays',)
# V1_PL -> ('study',)
# V1_PL -> ('cook',)
# V1_PL -> ('are',)
# V1_PL -> ('meet',)
# V1_PL -> ('speak',)
# V1_PL -> ('give',)
# V1_PL -> ('teach',)
# V1_PL -> ('turn',)
# V1_PL -> ('sing',)
# V1_PL -> ('drink',)
# V1_PL -> ('think',)
# V1_PL -> ('see',)
# V1_PL -> ('rain',)
# V1_PL -> ('do',)
# V1_PL -> ('take',)
# V1_PL -> ('go',)
# GERUNDV -> ('burning',)
# GERUNDV -> ('ringing',)
# GERUNDV -> ('having',)
# GERUNDV -> ('suffering',)
# GERUNDV -> ('dancing',)
# GERUNDV -> ('listening',)
# GERUNDV -> ('writing',)
# GERUNDV -> ('raining',)
# GERUNDV -> ('studying',)
# GERUNDV -> ('taking',)
# GERUNDV -> ('dating',)
# GERUNDV -> ('opening',)
# GERUNDV -> ('teaching',)
# GERUNDV -> ('waiting',)
# GERUNDV -> ('meeting',)
# GERUNDV -> ('playing',)
# GERUNDV -> ('running',)
# GERUNDV -> ('spending',)
# GERUNDV -> ('going',)
# GERUNDV -> ('climbing',)
# GERUNDV -> ('visiting',)
# GERUNDV -> ('seeing',)
# GERUNDV -> ('cleaning',)
# GERUNDV -> ('repairing',)
# GERUNDV -> ('snowing',)
# GERUNDV -> ('getting',)
# GERUNDV -> ('living',)
# GERUNDV -> ('looking',)
# GERUNDV -> ('feeling',)
# GERUNDV -> ('enjoying',)
# V2 -> ('were',)
# V2 -> ('did',)
# V2 -> ('received',)
# V2 -> ('saw',)
# V2 -> ('read',)
# V2 -> ('caught',)
# V2 -> ('started',)
# V2 -> ('made',)
# V2 -> ('would',)
# V2 -> ('gave',)
# V2 -> ('knew',)
# V2 -> ('married',)
# V2 -> ('tired',)
# V2 -> ('taught',)
# V2 -> ('drink',)
# V2 -> ('flew',)
# V2 -> ('understood',)
# V2 -> ('was',)
# V2 -> ('went',)
# V3 -> ('gone',)
# V3 -> ('watched',)
# V3 -> ('flown',)
# V3 -> ('written',)
# V3 -> ('given',)
# V3 -> ('seen',)
# V3 -> ('painted',)
# V3 -> ('done',)
# V3 -> ('fed',)
# V3 -> ('made',)
# V3 -> ('finished',)
# V3 -> ('met',)
# V3 -> ('acted',)

# %%
def first_follow(G) :
  def union(set1, set2):
    set1len = len(set1)
    set1 |= set2
    return set1len != len(set1)

  # initialising the data structures to store and first and follow values
  first = { symbol: set() for symbol in G.symbols }
  follow = { symbol: set() for symbol in G.symbols }

  for symbol in G.symbols :
    if symbol in G.terminals :
      first[symbol].add(symbol)

  follow[G.startSymbol].add('$')

  while True :
    updated = False

    for head, bodies in G.grammar.items() :
      for body in bodies :
        for symbol in body :
          if symbol != '^':
            updated |= union(first[head], first[symbol] - set('^'))
            if '^' not in first[symbol] :
              break
            else :
              updated |= union(first[head], set('^'))
        aux = follow[head]
        for symbol in reversed(body) :
          if symbol == '^':
            continue
          if symbol in follow:
            updated |= union(follow[symbol], aux - set('^'))
          if '^' in first[symbol] :
            aux = aux | first[symbol]
          else :
            aux = first[symbol]
    if not updated:
      return first, follow

# %%
# Construction of LR(0) items

# Computation of set of items constructed from I
# I - set of items for G
def CLOSURE(aug_G, I):
  J = I

  while True :
    item_len = len(J)
    for head, bodies in J.copy().items() :
      for body in bodies.copy():
        if '.' in body[:-1]:
          dot_pos = body.index('.')
          symbol_after_dot = body[dot_pos + 1]
          if symbol_after_dot in aug_G.nonterminals :
            for G_body in aug_G.grammar[symbol_after_dot]:
              if G_body == tuple('^'):
                J.setdefault(symbol_after_dot, set()).add(set('.'))
              else :
                J.setdefault(symbol_after_dot, set()).add(('.',) + G_body)
    if item_len == len(J):
      return J

# GOTO(I, X) defined to be the closure of the set of all items [A -> aX.b] such that [A -> a.Xb] is in I
# I - set of items
# X - grammar symbol
def GOTO(aug_G, I, X):
  goto = {}

  for head, bodies in I.items() :
    for body in bodies :
      if '.' in body[:-1]:
        dot_pos = body.index('.')
        if body[dot_pos + 1] == X :
          replaced_dot_body = body[ : dot_pos] + (X, '.') + body[dot_pos + 2: ]
          for C_head, C_bodies in CLOSURE(aug_G, {head: {replaced_dot_body}}).items():
            goto.setdefault(C_head, set()).update(C_bodies)

  return goto

# Construction of canonical collection of sets of LR(0) items for G'
def items(aug_G):
  C = [CLOSURE(aug_G, {aug_G.startSymbol : {('.', aug_G.startSymbol[:-1])}})]

  while True:
    item_len = len(C)
    for I in C.copy() :
      for X in aug_G.symbols:
        goto = GOTO(aug_G, I, X)
        if (len(goto) > 0) and goto not in C:
          C.append(goto)
    if item_len == len(C) :
      return C

# %%
class SLRParser:
  def __init__(self, G):
    self.aug_G = Grammar([f"{G.startSymbol}' -> {G.startSymbol}"] + G.input)
    self.max_aug_G_len = len(max(self.aug_G.grammar, key=len))

    self.G_indexed = []
    for head, bodies in self.aug_G.grammar.items():
      for body in bodies:
        self.G_indexed.append([head, body])

    self.first, self.follow = first_follow(self.aug_G)

    self.C = items(self.aug_G)

    self.action = list(self.aug_G.terminals) + ['$']
    self.goto = []
    for nonterminal in self.aug_G.nonterminals :
      if nonterminal != self.aug_G.startSymbol :
        self.goto.append(nonterminal)

    self.parse_table_symbols = self.action + self.goto
    self.parse_table = self.construct_table()

  def construct_table(self):
    # Step 1 - Construct C
    # Step 2 - parsing actions for state i are determined
    parse_table = {r: {c: '' for c in self.parse_table_symbols} for r in range(len(self.C))}

    for i, I in enumerate(self.C) :
      for head, bodies in I.items() :
        for body in bodies :
          if '.' in body[:-1] : # Case 2a
            dot_pos = body.index('.')
            symbol_after_dot = body[dot_pos + 1]

            if symbol_after_dot in self.aug_G.terminals :
              s = f's{self.C.index(GOTO(self.aug_G, I, symbol_after_dot))}'
              if s not in parse_table[i][symbol_after_dot]:
                if 'r' in parse_table[i][symbol_after_dot] :
                  parse_table[i][symbol_after_dot] += '/'
                parse_table[i][symbol_after_dot] += s

          elif body[-1] == '.' and head != self.aug_G.startSymbol : # Case 2b
            for j, (G_head, G_body) in enumerate(self.G_indexed) :
              if G_head == head and (G_body == body[:-1] or G_body == ('^',) and body == ('.',)):
                for f in self.follow[head] :
                  if parse_table[i][f] :
                    parse_table[i][f] += '/'
                  parse_table[i][f] += f'r{j}'

                break

          else : # Case 2c
            parse_table[i]['$'] = 'acc'

      # Step 3 - Goto transistions for all nonterminals are constructed
      for A in self.aug_G.nonterminals :
        j = GOTO(self.aug_G, I, A)
        if j in self.C :
          parse_table[i][A] = self.C.index(j)

    return parse_table

  def __str__ (self) :
    def fprint(text, variable) :
      print(f'{text:>12}: {", ".join(variable)}')
    def print_line() :
      print(f'+{("-" * width + "+") * (len(list(self.aug_G.symbols) + ["$"]))}')
    def symbols_width(symbols) :
      return (width + 1) * len(symbols) - 1

    print("Augmented Grammar : ")
    for i, (head, body) in enumerate(self.G_indexed):
      print(f'{i:>{len(str(len(self.G_indexed) - 1))}}: {head:>{self.max_aug_G_len}} -> {" ".join(body)}')
    print()
    fprint('TERMINALS', self.aug_G.terminals)
    fprint('NONTERMINALS', self.aug_G.nonterminals)
    fprint('SYMBOLS', self.aug_G.symbols)

    print('\nFIRST:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.first[head])} }}')

    print('\nFOLLOW:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.follow[head])} }}')

    width = max(len(c) for c in {'ACTION'} | self.aug_G.symbols) + 2
    for r in range(len(self.C)):
      max_len = max(len(str(c)) for c in self.parse_table[r].values())

      if width < max_len + 2:
        width = max_len + 2

    print('\nPARSING TABLE:')
    print(f'+{"-" * width}+{"-" * symbols_width(self.action)}+{"-" * symbols_width(self.goto)}+')
    print(f'|{"":{width}}|{"ACTION":^{symbols_width(self.action)}}|{"GOTO":^{symbols_width(self.goto)}}|')
    print(f'|{"STATE":^{width}}+{("-" * width + "+") * len(self.parse_table_symbols)}')
    print(f'|{"":^{width}}|', end=' ')

    for symbol in self.parse_table_symbols:
      print(f'{symbol:^{width - 1}}|', end=' ')

    print()
    print_line()

    for r in range(len(self.C)):
      print(f'|{r:^{width}}|', end=' ')

      for c in self.parse_table_symbols:
        print(f'{self.parse_table[r][c]:^{width - 1}}|', end=' ')

      print()

    print_line()
    print()
    return ""

# %%
slr = SLRParser(G)
print(slr)
# Out:
# Augmented Grammar :
#   0:                   S' -> S
#   1:                    S -> NP_PL FUTURE_PERFECT_CONT S1
#   2:                    S -> NP_PL PAST_PERFECT S1
#   3:                    S -> NP_SG PAST_CONT_SG S1
#   4:                    S -> NP_PL PAST_PERFECT_CONT S1
#   5:                    S -> NP_SG PRES_CONT_SG S1
#   6:                    S -> NP_PL PRES_PL S1
#   7:                    S -> NP_SG FUTURE S1
#   8:                    S -> NP_PL PRES_CONT_PL S1
#   9:                    S -> NP_PL FUTURE_PERFECT S1
#  10:                    S -> NP_PL PAST_CONT_PL S1
#  11:                    S -> NP_PL PAST S1
#  12:                    S -> NP_PL FUTURE_CONT S1
#  13:                    S -> NP_SG PRES_PERFECT_SG S1
#  14:                    S -> NP_SG FUTURE_PERFECT_CONT S1
#  15:                    S -> NP_SG PAST_PERFECT S1
#  16:                    S -> NP_PL PRES_PERFECT_PL S1
#  17:                    S -> NP_SG PAST_PERFECT_CONT S1
#  18:                    S -> NP_PL FUTURE S1
#  19:                    S -> NP_PL PRES_PERFECT_CONT_PL S1
#  20:                    S -> S ADV
#  21:                    S -> NP_SG FUTURE_PERFECT S1
#  22:                    S -> NP_SG PRES_PERFECT_CONT_SG S1
#  23:                    S -> NP_SG PAST S1
#  24:                    S -> NP_SG PRES_SG S1
#  25:                    S -> NP_SG FUTURE_CONT S1
#  26:                   S1 -> ADV
#  27:                   S1 -> NP
#  28:                   NP -> PP
#  29:                   NP -> NP_SG
#  30:                   NP -> NP PP
#  31:                   NP -> NP_PL
#  32:                NP_SG -> ADV NP_SG
#  33:                NP_SG -> PRONOUN_SG NOM_SG
#  34:                NP_SG -> NOM_SG
#  35:                NP_SG -> DET_BOTH NOM_SG
#  36:                NP_SG -> DET_SG NOM_SG
#  37:                NP_SG -> PRONOUN_SG
#  38:                NP_SG -> PROPERNOUN
#  39:                NP_SG -> NP_SG CONJ NP
#  40:               NOM_SG -> NOUN_SG
#  41:               NOM_SG -> NOM_SG NOUN_SG
#  42:               NOM_SG -> ADJ NOUN_SG
#  43:                NP_PL -> DET_PL NOM_PL
#  44:                NP_PL -> ADV NP_PL
#  45:                NP_PL -> NP_PL CONJ NP
#  46:                NP_PL -> PRONOUN_PL NOM_PL
#  47:                NP_PL -> PRONOUN_PL
#  48:                NP_PL -> NOM_PL
#  49:                NP_PL -> DET_BOTH NOM_PL
#  50:               NOM_PL -> NOUN_PL
#  51:               NOM_PL -> NOM_PL NOUN_PL
#  52:               NOM_PL -> ADJ NOUN_PL
#  53:                   PP -> PREPOS NP_SG
#  54:                   PP -> PREPOS NP_PL
#  55:                 PAST -> ADV V2
#  56:                 PAST -> V2
#  57:         PAST_PERFECT -> had ADV V3
#  58:         PAST_PERFECT -> had V3
#  59:         PAST_CONT_SG -> was ADV GERUNDV
#  60:         PAST_CONT_SG -> was GERUNDV
#  61:         PAST_CONT_PL -> were GERUNDV
#  62:         PAST_CONT_PL -> were ADV GERUNDV
#  63:    PAST_PERFECT_CONT -> had ADV been GERUNDV
#  64:    PAST_PERFECT_CONT -> had been GERUNDV
#  65:              PRES_SG -> ADV V1_SG
#  66:              PRES_SG -> V1_SG
#  67:              PRES_PL -> ADV V1_PL
#  68:              PRES_PL -> V1_PL
#  69:      PRES_PERFECT_SG -> has ADV V3
#  70:      PRES_PERFECT_SG -> has V3
#  71:      PRES_PERFECT_PL -> have V3
#  72:      PRES_PERFECT_PL -> have ADV V3
#  73:         PRES_CONT_SG -> is GERUNDV
#  74:         PRES_CONT_SG -> is ADV GERUNDV
#  75:         PRES_CONT_PL -> are GERUNDV
#  76:         PRES_CONT_PL -> are ADV GERUNDV
#  77: PRES_PERFECT_CONT_SG -> has been GERUNDV
#  78: PRES_PERFECT_CONT_SG -> has ADV been
#  79: PRES_PERFECT_CONT_SG -> has been
#  80: PRES_PERFECT_CONT_SG -> has ADV been GERUNDV
#  81: PRES_PERFECT_CONT_PL -> have been GERUNDV
#  82: PRES_PERFECT_CONT_PL -> have ADV been GERUNDV
#  83:               FUTURE -> will V1_PL
#  84:               FUTURE -> will ADV V1_PL
#  85:       FUTURE_PERFECT -> will have ADV V3
#  86:       FUTURE_PERFECT -> will have V3
#  87:          FUTURE_CONT -> will ADV be GERUNDV
#  88:          FUTURE_CONT -> will be GERUNDV
#  89:  FUTURE_PERFECT_CONT -> will have been GERUNDV
#  90:  FUTURE_PERFECT_CONT -> will have ADV been GERUNDV
#  91:           PRONOUN_SG -> him
#  92:           PRONOUN_SG -> it
#  93:           PRONOUN_SG -> he
#  94:           PRONOUN_SG -> my
#  95:           PRONOUN_SG -> his
#  96:           PRONOUN_SG -> she
#  97:           PRONOUN_SG -> i
#  98:           PRONOUN_SG -> her
#  99:           PRONOUN_PL -> you
# 100:           PRONOUN_PL -> us
# 101:           PRONOUN_PL -> we
# 102:           PRONOUN_PL -> their
# 103:           PRONOUN_PL -> they
# 104:             RELPR_SG -> which
# 105:             RELPR_PL -> whom
# 106:           PROPERNOUN -> may
# 107:           PROPERNOUN -> easter
# 108:           PROPERNOUN -> january
# 109:           PROPERNOUN -> switzerland
# 110:           PROPERNOUN -> ajitesh
# 111:           PROPERNOUN -> germany
# 112:           PROPERNOUN -> wednesday
# 113:           PROPERNOUN -> joseph
# 114:           PROPERNOUN -> navvya
# 115:           PROPERNOUN -> november
# 116:           PROPERNOUN -> turkey
# 117:           PROPERNOUN -> ritheesh
# 118:           PROPERNOUN -> john
# 119:           PROPERNOUN -> ishwarya
# 120:           PROPERNOUN -> america
# 121:           PROPERNOUN -> canada
# 122:           PROPERNOUN -> paris
# 123:           PROPERNOUN -> raj
# 124:           PROPERNOUN -> india
# 125:              NOUN_SG -> picture
# 126:              NOUN_SG -> school
# 127:              NOUN_SG -> moment
# 128:              NOUN_SG -> food
# 129:              NOUN_SG -> outlet
# 130:              NOUN_SG -> brother
# 131:              NOUN_SG -> car
# 132:              NOUN_SG -> room
# 133:              NOUN_SG -> month
# 134:              NOUN_SG -> cup
# 135:              NOUN_SG -> night
# 136:              NOUN_SG -> friend
# 137:              NOUN_SG -> patient
# 138:              NOUN_SG -> airport
# 139:              NOUN_SG -> basketball
# 140:              NOUN_SG -> pilot
# 141:              NOUN_SG -> airplane
# 142:              NOUN_SG -> garden
# 143:              NOUN_SG -> year
# 144:              NOUN_SG -> movie
# 145:              NOUN_SG -> pope
# 146:              NOUN_SG -> weather
# 147:              NOUN_SG -> show
# 148:              NOUN_SG -> kabaddi
# 149:              NOUN_SG -> sister
# 150:              NOUN_SG -> house
# 151:              NOUN_SG -> evening
# 152:              NOUN_SG -> mom
# 153:              NOUN_SG -> bed
# 154:              NOUN_SG -> book
# 155:              NOUN_SG -> mountain
# 156:              NOUN_SG -> tea
# 157:              NOUN_SG -> album
# 158:              NOUN_SG -> song
# 159:              NOUN_SG -> letter
# 160:              NOUN_SG -> me
# 161:              NOUN_SG -> street
# 162:              NOUN_SG -> phone
# 163:              NOUN_SG -> party
# 164:              NOUN_SG -> parcel
# 165:              NOUN_SG -> sentence
# 166:              NOUN_SG -> weekend
# 167:              NOUN_SG -> call
# 168:              NOUN_SG -> assignment
# 169:              NOUN_SG -> thinking
# 170:              NOUN_SG -> baby
# 171:              NOUN_SG -> husband
# 172:              NOUN_SG -> football
# 173:              NOUN_SG -> fire
# 174:              NOUN_SG -> dad
# 175:              NOUN_SG -> wife
# 176:              NOUN_SG -> grandfather
# 177:              NOUN_SG -> player
# 178:              NOUN_SG -> afternoon
# 179:              NOUN_SG -> programming
# 180:              NOUN_SG -> building
# 181:              NOUN_SG -> accident
# 182:              NOUN_SG -> cold
# 183:              NOUN_SG -> neighbourhood
# 184:              NOUN_SG -> topper
# 185:              NOUN_SG -> homework
# 186:              NOUN_SG -> week
# 187:              NOUN_SG -> teacher
# 188:              NOUN_SG -> morning
# 189:              NOUN_SG -> fog
# 190:              NOUN_SG -> zoo
# 191:              NOUN_SG -> milk
# 192:              NOUN_SG -> accountant
# 193:              NOUN_PL -> ages
# 194:              NOUN_PL -> mountains
# 195:              NOUN_PL -> emails
# 196:              NOUN_PL -> specialists
# 197:              NOUN_PL -> portraits
# 198:              NOUN_PL -> cows
# 199:              NOUN_PL -> girls
# 200:              NOUN_PL -> boys
# 201:              NOUN_PL -> years
# 202:              NOUN_PL -> friends
# 203:              NOUN_PL -> roses
# 204:              NOUN_PL -> weeks
# 205:              NOUN_PL -> films
# 206:              NOUN_PL -> parents
# 207:              NOUN_PL -> goats
# 208:              NOUN_PL -> letters
# 209:              NOUN_PL -> people
# 210:              NOUN_PL -> children
# 211:              NOUN_PL -> jacksons
# 212:              NOUN_PL -> times
# 213:              NOUN_PL -> books
# 214:              NOUN_PL -> peacocks
# 215:               DET_SG -> that
# 216:               DET_SG -> this
# 217:               DET_SG -> an
# 218:               DET_SG -> a
# 219:               DET_PL -> all
# 220:               DET_PL -> these
# 221:               DET_PL -> many
# 222:               DET_PL -> no
# 223:             DET_BOTH -> the
# 224:                 CONJ -> and
# 225:                 CONJ -> because
# 226:                 CONJ -> but
# 227:                 CONJ -> while
# 228:                  ADJ -> nice
# 229:                  ADJ -> new
# 230:                  ADJ -> sweet
# 231:                  ADJ -> since
# 232:                  ADJ -> delicious
# 233:                  ADJ -> hungry
# 234:                  ADJ -> first
# 235:                  ADJ -> critical
# 236:                  ADJ -> every
# 237:                  ADJ -> last
# 238:                  ADJ -> whole
# 239:                  ADJ -> red
# 240:                  ADJ -> four
# 241:                  ADJ -> fun
# 242:                  ADJ -> two
# 243:                  ADJ -> three
# 244:                  ADJ -> severe
# 245:                  ADJ -> few
# 246:                  ADJ -> terrible
# 247:                  ADV -> not
# 248:                  ADV -> never
# 249:                  ADV -> ago
# 250:                  ADV -> well
# 251:                  ADV -> today
# 252:                  ADV -> gracefully
# 253:                  ADV -> twice
# 254:                  ADV -> early
# 255:                  ADV -> yesterday
# 256:                  ADV -> already
# 257:                  ADV -> when
# 258:                  ADV -> heavily
# 259:                  ADV -> always
# 260:                  ADV -> past
# 261:                  ADV -> whereabouts
# 262:                  ADV -> constantly
# 263:                  ADV -> lately
# 264:                  ADV -> tomorrow
# 265:                  ADV -> still
# 266:                  ADV -> very
# 267:                  ADV -> next
# 268:                  ADV -> recently
# 269:                  ADV -> before
# 270:               PREPOS -> from
# 271:               PREPOS -> by
# 272:               PREPOS -> down
# 273:               PREPOS -> for
# 274:               PREPOS -> of
# 275:               PREPOS -> on
# 276:               PREPOS -> far
# 277:               PREPOS -> to
# 278:               PREPOS -> at
# 279:               PREPOS -> as
# 280:               PREPOS -> around
# 281:               PREPOS -> in
# 282:                V1_SG -> teaches
# 283:                V1_SG -> be
# 284:                V1_SG -> sings
# 285:                V1_SG -> invloves
# 286:                V1_SG -> cooks
# 287:                V1_SG -> likes
# 288:                V1_SG -> know
# 289:                V1_SG -> am
# 290:                V1_SG -> climbs
# 291:                V1_SG -> works
# 292:                V1_SG -> is
# 293:                V1_SG -> draws
# 294:                V1_SG -> understands
# 295:                V1_SG -> plays
# 296:                V1_PL -> study
# 297:                V1_PL -> cook
# 298:                V1_PL -> are
# 299:                V1_PL -> meet
# 300:                V1_PL -> speak
# 301:                V1_PL -> give
# 302:                V1_PL -> teach
# 303:                V1_PL -> turn
# 304:                V1_PL -> sing
# 305:                V1_PL -> drink
# 306:                V1_PL -> think
# 307:                V1_PL -> see
# 308:                V1_PL -> rain
# 309:                V1_PL -> do
# 310:                V1_PL -> take
# 311:                V1_PL -> go
# 312:              GERUNDV -> burning
# 313:              GERUNDV -> ringing
# 314:              GERUNDV -> having
# 315:              GERUNDV -> suffering
# 316:              GERUNDV -> dancing
# 317:              GERUNDV -> listening
# 318:              GERUNDV -> writing
# 319:              GERUNDV -> raining
# 320:              GERUNDV -> studying
# 321:              GERUNDV -> taking
# 322:              GERUNDV -> dating
# 323:              GERUNDV -> opening
# 324:              GERUNDV -> teaching
# 325:              GERUNDV -> waiting
# 326:              GERUNDV -> meeting
# 327:              GERUNDV -> playing
# 328:              GERUNDV -> running
# 329:              GERUNDV -> spending
# 330:              GERUNDV -> going
# 331:              GERUNDV -> climbing
# 332:              GERUNDV -> visiting
# 333:              GERUNDV -> seeing
# 334:              GERUNDV -> cleaning
# 335:              GERUNDV -> repairing
# 336:              GERUNDV -> snowing
# 337:              GERUNDV -> getting
# 338:              GERUNDV -> living
# 339:              GERUNDV -> looking
# 340:              GERUNDV -> feeling
# 341:              GERUNDV -> enjoying
# 342:                   V2 -> were
# 343:                   V2 -> did
# 344:                   V2 -> received
# 345:                   V2 -> saw
# 346:                   V2 -> read
# 347:                   V2 -> caught
# 348:                   V2 -> started
# 349:                   V2 -> made
# 350:                   V2 -> would
# 351:                   V2 -> gave
# 352:                   V2 -> knew
# 353:                   V2 -> married
# 354:                   V2 -> tired
# 355:                   V2 -> taught
# 356:                   V2 -> drink
# 357:                   V2 -> flew
# 358:                   V2 -> understood
# 359:                   V2 -> was
# 360:                   V2 -> went
# 361:                   V3 -> gone
# 362:                   V3 -> watched
# 363:                   V3 -> flown
# 364:                   V3 -> written
# 365:                   V3 -> given
# 366:                   V3 -> seen
# 367:                   V3 -> painted
# 368:                   V3 -> done
# 369:                   V3 -> fed
# 370:                   V3 -> made
# 371:                   V3 -> finished
# 372:                   V3 -> met
# 373:                   V3 -> acted
#
#    TERMINALS: programming, call, room, weekend, to, draws, patient, rain, flown, done, already, whereabouts, america, mom, nice, far, evening, boys, and, know, recently, garden, repairing, flew, pope, seen, cook, germany, tomorrow, waiting, morning, sweet, new, are, is, football, early, sings, us, dancing, week, would, cup, fed, because, suffering, climbing, jacksons, album, show, parcel, not, bed, these, had, around, dating, him, thinking, see, a, think, terrible, neighbourhood, switzerland, feeling, afternoon, written, past, first, books, she, as, on, turkey, night, that, yesterday, give, gave, invloves, john, january, next, letter, down, am, climbs, accountant, raining, husband, be, year, getting, have, sing, very, lately, month, teacher, playing, heavily, drink, living, house, received, weeks, tired, assignment, meet, sentence, raj, severe, car, caught, this, many, was, peacocks, running, hungry, go, grandfather, watched, people, at, last, years, ritheesh, before, been, we, outlet, whole, ishwarya, wife, for, two, baby, enjoying, ajitesh, take, school, well, ages, visiting, specialists, of, gracefully, three, from, every, were, while, when, turn, milk, painted, tea, snowing, mountains, cleaning, meeting, likes, writing, acted, zoo, airplane, picture, few, it, constantly, teaching, married, critical, basketball, burning, movie, parents, red, never, saw, canada, went, his, studying, song, he, friend, listening, twice, airport, wednesday, india, an, their, her, fun, given, since, still, plays, fire, films, pilot, the, kabaddi, ago, you, all, cold, read, cooks, did, seeing, sister, cows, i, four, teach, spending, navvya, times, understood, goats, always, do, homework, will, emails, understands, by, topper, no, today, moment, building, gone, phone, having, food, has, november, taking, ringing, easter, in, finished, study, joseph, letters, accident, they, knew, children, started, fog, weather, friends, book, but, works, made, roses, player, may, taught, met, mountain, delicious, opening, party, street, dad, girls, looking, me, whom, speak, brother, portraits, paris, going, which, teaches, my
# NONTERMINALS: NP_PL, S', S1, V2, PRES_SG, PP, S, FUTURE_PERFECT_CONT, PAST_CONT_SG, PAST_PERFECT_CONT, PRES_PL, ADV, PRES_PERFECT_SG, NOM_SG, NOUN_SG, PRES_PERFECT_CONT_PL, PREPOS, GERUNDV, DET_BOTH, PAST_CONT_PL, FUTURE_CONT, NOUN_PL, ADJ, V1_PL, FUTURE_PERFECT, PAST_PERFECT, NOM_PL, PAST, PRES_PERFECT_PL, NP, PROPERNOUN, PRES_CONT_PL, CONJ, V1_SG, FUTURE, PRONOUN_PL, PRES_CONT_SG, RELPR_SG, DET_SG, RELPR_PL, NP_SG, V3, PRONOUN_SG, PRES_PERFECT_CONT_SG, DET_PL
#      SYMBOLS: programming, room, to, patient, FUTURE_PERFECT_CONT, PAST_CONT_SG, flown, done, PRES_PL, far, america, nice, evening, know, repairing, recently, garden, morning, sweet, new, are, football, dancing, week, fed, cup, because, suffering, jacksons, PRONOUN_PL, show, bed, dating, him, PRES_PERFECT_CONT_SG, see, DET_PL, a, think, terrible, neighbourhood, switzerland, feeling, first, she, on, turkey, that, yesterday, climbs, john, january, next, raining, be, year, have, very, living, month, playing, house, weeks, PRES_PERFECT_CONT_PL, assignment, sentence, severe, ADJ, this, many, was, PROPERNOUN, watched, last, years, ritheesh, before, outlet, ishwarya, wife, S', enjoying, ajitesh, take, school, ages, S, three, PAST_PERFECT_CONT, were, turn, ADV, PRES_PERFECT_SG, mountains, NOUN_SG, cleaning, acted, airplane, teaching, DET_BOTH, constantly, married, PAST_CONT_PL, burning, red, saw, canada, went, his, NOM_PL, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, cooks, did, sister, four, understood, spending, do, homework, will, understands, by, topper, no, today, moment, NOM_SG, phone, has, easter, in, finished, FUTURE_PERFECT, weather, player, met, delicious, party, RELPR_PL, DET_SG, dad, girls, me, portraits, children, paris, going, boys, NP_PL, these, call, V2, weekend, draws, rain, already, whereabouts, mom, flew, and, seen, pope, cook, germany, GERUNDV, tomorrow, waiting, is, V1_PL, early, sings, us, would, climbing, album, parcel, not, had, around, thinking, PRONOUN_SG, afternoon, written, past, as, books, give, night, gave, PP, invloves, letter, down, am, accountant, getting, husband, sing, lately, teacher, heavily, drink, received, tired, meet, raj, car, caught, peacocks, PAST, running, PRES_PERFECT_PL, hungry, go, grandfather, people, at, which, been, we, V3, whole, for, two, baby, well, visiting, specialists, of, gracefully, from, every, while, when, milk, painted, tea, snowing, meeting, likes, writing, zoo, PREPOS, picture, few, it, critical, basketball, movie, parents, never, studying, song, V1_SG, listening, FUTURE, airport, wednesday, india, an, their, given, since, PRES_CONT_SG, plays, NP_SG, the, all, cold, read, S1, seeing, PRES_SG, cows, teach, navvya, times, goats, always, emails, building, gone, having, food, november, taking, ringing, study, FUTURE_CONT, NOUN_PL, joseph, letters, PAST_PERFECT, accident, they, knew, NP, CONJ, PRES_CONT_PL, started, fog, friends, book, but, works, made, may, taught, mountain, opening, RELPR_SG, street, looking, whom, speak, brother, roses, her, i, teaches, my
#
# FIRST:
#                   S' = { programming, room, patient, america, nice, evening, recently, garden, sweet, morning, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, topper, no, today, moment, phone, easter, weather, player, delicious, girls, party, dad, me, portraits, paris, children, boys, these, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, thinking, afternoon, past, books, night, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, we, whole, two, baby, well, specialists, gracefully, every, when, milk, tea, zoo, few, picture, it, critical, basketball, parents, movie, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#                    S = { programming, room, patient, america, nice, evening, recently, garden, sweet, morning, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, topper, no, today, moment, phone, easter, weather, player, delicious, girls, party, dad, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, thinking, afternoon, past, books, night, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, we, whole, two, baby, well, specialists, gracefully, every, when, milk, tea, zoo, few, picture, it, critical, basketball, parents, movie, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#                   S1 = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#                   NP = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, from, gracefully, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#                NP_SG = { programming, call, room, weekend, patient, already, whereabouts, america, mom, nice, evening, recently, garden, pope, tomorrow, germany, morning, sweet, new, football, early, week, cup, album, show, parcel, not, bed, him, thinking, a, terrible, neighbourhood, switzerland, afternoon, past, first, she, turkey, yesterday, that, night, john, next, january, letter, accountant, husband, year, very, lately, month, teacher, heavily, house, assignment, sentence, raj, severe, car, this, hungry, grandfather, last, ritheesh, before, outlet, whole, ishwarya, wife, two, baby, ajitesh, school, well, gracefully, three, every, when, milk, tea, zoo, airplane, picture, few, it, constantly, critical, basketball, movie, never, red, canada, his, song, he, friend, twice, airport, an, wednesday, india, fun, since, still, fire, pilot, the, kabaddi, ago, cold, sister, four, navvya, paris, always, homework, topper, today, moment, building, phone, food, november, easter, joseph, accident, fog, weather, book, player, may, mountain, delicious, party, street, dad, me, brother, her, i, my }
#               NOM_SG = { programming, call, room, weekend, patient, mom, nice, evening, garden, pope, morning, sweet, new, football, week, cup, album, show, parcel, bed, thinking, terrible, neighbourhood, afternoon, first, night, letter, accountant, husband, year, month, teacher, house, assignment, sentence, severe, car, hungry, grandfather, last, outlet, whole, wife, two, baby, school, three, every, milk, tea, zoo, airplane, picture, few, critical, basketball, movie, red, song, friend, airport, fun, since, fire, pilot, kabaddi, cold, sister, four, homework, topper, moment, building, phone, food, accident, fog, weather, book, player, mountain, delicious, party, street, dad, me, brother }
#                NP_PL = { two, well, ages, specialists, gracefully, three, every, already, when, whereabouts, nice, mountains, recently, tomorrow, few, constantly, sweet, critical, new, parents, never, red, early, us, twice, jacksons, fun, their, since, not, these, still, films, the, ago, terrible, you, all, past, first, books, cows, yesterday, four, times, always, next, goats, emails, very, no, lately, today, heavily, weeks, severe, many, letters, portraits, peacocks, they, friends, hungry, people, delicious, last, years, girls, before, we, whole, roses, children, boys }
#               NOM_PL = { two, ages, specialists, three, every, nice, mountains, few, sweet, critical, new, parents, red, jacksons, fun, since, films, terrible, first, books, cows, four, times, goats, emails, weeks, severe, letters, peacocks, friends, hungry, roses, people, delicious, last, years, girls, whole, portraits, children, boys }
#                   PP = { as, on, to, of, from, down, by, at, far, around, in, for }
#                 PAST = { read, past, did, yesterday, well, gave, understood, always, next, gracefully, already, were, when, very, lately, today, whereabouts, heavily, drink, received, flew, recently, tired, tomorrow, constantly, married, never, saw, went, caught, early, was, knew, would, started, twice, made, taught, not, still, before, ago }
#         PAST_PERFECT = { had }
#         PAST_CONT_SG = { was }
#         PAST_CONT_PL = { were }
#    PAST_PERFECT_CONT = { had }
#              PRES_SG = { past, cooks, yesterday, well, draws, invloves, climbs, always, next, gracefully, am, understands, be, already, when, very, lately, today, whereabouts, heavily, know, likes, recently, tomorrow, constantly, never, is, early, sings, works, twice, not, still, before, plays, ago, teaches }
#              PRES_PL = { past, take, give, yesterday, well, teach, always, next, gracefully, do, rain, already, sing, when, turn, very, lately, today, whereabouts, think, heavily, drink, recently, cook, tomorrow, meet, constantly, are, study, never, early, go, twice, not, still, before, speak, see, ago }
#      PRES_PERFECT_SG = { has }
#      PRES_PERFECT_PL = { have }
#         PRES_CONT_SG = { is }
#         PRES_CONT_PL = { are }
# PRES_PERFECT_CONT_SG = { has }
# PRES_PERFECT_CONT_PL = { have }
#               FUTURE = { will }
#       FUTURE_PERFECT = { will }
#          FUTURE_CONT = { will }
#  FUTURE_PERFECT_CONT = { will }
#           PRONOUN_SG = { she, his, him, he, it, her, i, my }
#           PRONOUN_PL = { they, their, you, us, we }
#             RELPR_SG = { which }
#             RELPR_PL = { whom }
#           PROPERNOUN = { canada, ajitesh, joseph, turkey, navvya, john, january, may, wednesday, india, america, ritheesh, november, germany, ishwarya, paris, easter, raj, switzerland }
#              NOUN_SG = { afternoon, cold, baby, programming, call, school, night, sister, room, weekend, patient, letter, homework, accountant, husband, year, topper, milk, month, moment, mom, tea, building, teacher, evening, house, phone, garden, food, pope, zoo, airplane, picture, assignment, morning, sentence, basketball, movie, car, football, song, accident, week, cup, friend, weather, fog, book, grandfather, airport, player, mountain, show, album, parcel, bed, party, street, dad, outlet, me, thinking, fire, pilot, brother, kabaddi, neighbourhood, wife }
#              NOUN_PL = { parents, books, cows, letters, peacocks, ages, times, specialists, goats, friends, emails, roses, people, jacksons, years, mountains, girls, weeks, films, portraits, children, boys }
#               DET_SG = { this, a, that, an }
#               DET_PL = { no, many, all, these }
#             DET_BOTH = { the }
#                 CONJ = { while, because, but, and }
#                  ADJ = { two, red, severe, first, four, terrible, three, every, hungry, fun, delicious, last, since, nice, whole, few, sweet, critical, new }
#                  ADV = { never, past, early, yesterday, well, always, next, gracefully, twice, already, when, very, lately, today, whereabouts, heavily, not, still, before, recently, tomorrow, constantly, ago }
#               PREPOS = { at, as, far, on, around, to, of, from, down, by, in, for }
#                V1_SG = { is, cooks, sings, know, likes, draws, plays, invloves, teaches, climbs, works, am, understands, be }
#                V1_PL = { are, study, turn, sing, take, drink, give, teach, do, cook, speak, meet, see, rain, think, go }
#              GERUNDV = { enjoying, seeing, studying, dancing, spending, visiting, running, raining, listening, getting, suffering, climbing, living, playing, snowing, opening, cleaning, meeting, writing, repairing, having, dating, taking, looking, waiting, ringing, going, feeling, teaching, burning }
#                   V2 = { read, saw, went, did, caught, gave, understood, was, knew, would, started, made, were, taught, drink, received, flew, tired, married }
#                   V3 = { given, written, met, painted, gone, seen, acted, fed, flown, done, made, watched, finished }
#
# FOLLOW:
#                   S' = { $ }
#                    S = { past, yesterday, well, always, next, gracefully, already, when, very, lately, today, whereabouts, heavily, recently, tomorrow, constantly, never, early, twice, not, still, before, $, ago }
#                   S1 = { past, yesterday, well, always, next, gracefully, already, when, very, lately, today, whereabouts, heavily, recently, tomorrow, constantly, never, early, twice, not, still, before, $, ago }
#                   NP = { to, draws, rain, already, whereabouts, far, flew, and, know, recently, cook, tomorrow, are, is, early, sings, would, because, not, had, around, see, think, past, as, on, give, yesterday, gave, invloves, climbs, next, down, am, be, have, sing, very, lately, heavily, drink, received, tired, meet, caught, was, go, at, before, for, take, well, of, gracefully, from, were, when, while, turn, likes, constantly, married, never, saw, went, twice, still, plays, $, ago, read, did, cooks, understood, teach, always, do, will, understands, by, today, has, in, study, knew, started, works, but, made, taught, speak, teaches }
#                NP_SG = { draws, to, rain, already, whereabouts, far, flew, and, know, recently, cook, tomorrow, are, is, early, sings, would, because, not, had, around, see, think, past, as, on, give, yesterday, gave, invloves, climbs, next, down, am, be, have, sing, very, lately, heavily, drink, received, tired, meet, caught, was, go, at, before, for, take, well, of, gracefully, from, were, when, while, turn, likes, constantly, married, never, saw, went, twice, still, plays, $, ago, read, did, cooks, understood, teach, always, do, will, understands, by, today, has, in, study, knew, started, works, but, made, taught, speak, teaches }
#               NOM_SG = { programming, call, room, weekend, draws, to, patient, rain, already, whereabouts, mom, far, evening, flew, and, know, recently, garden, pope, cook, tomorrow, morning, are, is, football, early, sings, week, would, cup, because, album, show, parcel, not, bed, had, around, thinking, see, think, neighbourhood, afternoon, past, as, on, night, yesterday, gave, give, invloves, climbs, next, letter, down, am, accountant, husband, be, year, have, sing, very, lately, month, teacher, heavily, drink, house, received, tired, assignment, meet, sentence, car, caught, was, go, grandfather, at, before, outlet, wife, for, baby, take, school, well, of, gracefully, from, were, when, while, turn, milk, tea, likes, zoo, airplane, picture, constantly, married, basketball, movie, never, saw, went, song, friend, twice, airport, still, plays, $, fire, pilot, kabaddi, ago, cold, read, did, cooks, sister, understood, teach, always, do, homework, will, understands, by, topper, today, moment, building, phone, food, has, in, study, accident, knew, started, fog, weather, works, book, but, made, player, taught, mountain, party, street, dad, me, speak, brother, teaches }
#                NP_PL = { to, draws, rain, already, whereabouts, far, flew, and, know, recently, cook, tomorrow, are, is, early, sings, would, because, not, had, around, see, think, past, as, give, on, yesterday, gave, invloves, climbs, next, down, am, be, have, sing, very, lately, heavily, drink, received, tired, meet, caught, was, go, at, before, for, take, well, of, gracefully, from, were, when, while, turn, likes, constantly, married, never, saw, went, twice, still, plays, $, ago, read, did, cooks, teach, understood, always, do, will, understands, by, today, has, in, study, knew, started, works, but, made, taught, speak, teaches }
#               NOM_PL = { to, draws, rain, already, whereabouts, far, flew, and, know, recently, cook, tomorrow, are, is, early, sings, would, because, jacksons, not, had, around, see, think, past, as, books, give, on, yesterday, gave, invloves, climbs, next, down, am, be, have, sing, very, lately, heavily, drink, received, weeks, tired, meet, caught, was, peacocks, go, people, at, years, before, for, take, well, ages, specialists, of, gracefully, from, were, when, while, turn, mountains, likes, constantly, married, parents, never, saw, went, twice, still, plays, $, films, ago, read, did, cooks, cows, teach, understood, times, always, goats, do, will, emails, understands, by, today, has, in, study, letters, knew, started, works, friends, but, made, roses, taught, girls, speak, portraits, children, teaches, boys }
#                   PP = { to, draws, rain, already, whereabouts, far, flew, and, know, recently, cook, tomorrow, are, is, early, sings, would, because, not, had, around, see, think, past, as, on, give, yesterday, gave, invloves, climbs, next, down, am, be, have, sing, very, lately, heavily, drink, received, tired, meet, caught, was, go, at, before, for, take, well, of, gracefully, from, were, when, while, turn, likes, constantly, married, never, saw, went, twice, still, plays, $, ago, read, did, cooks, understood, teach, always, do, will, understands, by, today, has, in, study, knew, started, works, but, made, taught, speak, teaches }
#                 PAST = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#         PAST_PERFECT = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#         PAST_CONT_SG = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#         PAST_CONT_PL = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#    PAST_PERFECT_CONT = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#              PRES_SG = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#              PRES_PL = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
#      PRES_PERFECT_SG = { programming, room, to, patient, far, america, nice, evening, recently, garden, morning, sweet, new, football, week, cup, jacksons, show, bed, him, a, terrible, neighbourhood, switzerland, first, she, on, turkey, yesterday, that, john, next, january, year, very, month, house, weeks, assignment, sentence, severe, this, many, last, years, ritheesh, before, outlet, ishwarya, wife, ajitesh, school, ages, three, mountains, airplane, constantly, red, canada, his, he, friend, twice, fun, still, fire, films, pilot, kabaddi, ago, you, sister, four, homework, by, topper, no, today, moment, phone, easter, in, weather, player, delicious, party, dad, girls, me, portraits, paris, children, these, boys, call, weekend, already, whereabouts, mom, pope, tomorrow, germany, early, us, album, parcel, not, around, thinking, afternoon, past, as, books, night, down, letter, accountant, husband, lately, teacher, heavily, raj, car, peacocks, hungry, grandfather, people, at, we, whole, for, two, baby, well, specialists, of, gracefully, from, every, when, milk, tea, zoo, picture, few, it, critical, basketball, movie, parents, never, song, airport, an, wednesday, india, their, since, the, all, cold, cows, navvya, times, always, goats, emails, building, food, november, joseph, letters, accident, they, fog, friends, book, may, mountain, street, brother, roses, her, i, my }
# ...
# |         438          |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |                      |                      |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |                      |          r80         |          r80         |                      |                      |          r80         |                      |                      |          r80         |          r80         |                      |          r80         |          r80         |          r80         |                      |                      |          r80         |          r80         |                      |          r80         |                      |          r80         |                      |          r80         |                      |                      |                      |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |                      |          r80         |          r80         |                      |          r80         |                      |          r80         |          r80         |          r80         |                      |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |                      |                      |          r80         |          r80         |          r80         |          r80         |          r80         |                      |                      |          r80         |                      |          r80         |                      |          r80         |                      |                      |                      |          r80         |          r80         |          r80         |          r80         |                      |          r80         |                      |                      |          r80         |                      |          r80         |                      |          r80         |                      |          r80         |          r80         |          r80         |          r80         |                      |          r80         |          r80         |                      |          r80         |                      |          r80         |                      |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |          r80         |                      |          r80         |          r80         |          r80         |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                      |                      |          r80         |                      |          r80         |                      |          r80         |                      |          r80         |                      |                      |                      |                      |                      |          r80         |          r80         |          r80         |          r80         |          r80         |          r80         |                     ...
# |         439          |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |                      |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |          r90         |          r90         |                      |                      |          r90         |                      |                      |          r90         |          r90         |                      |          r90         |          r90         |          r90         |                      |                      |          r90         |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |                      |                      |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |                      |          r90         |          r90         |                      |          r90         |                      |          r90         |          r90         |          r90         |                      |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |          r90         |                      |          r90         |                      |          r90         |                      |                      |                      |          r90         |          r90         |          r90         |          r90         |                      |          r90         |                      |                      |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |          r90         |                      |          r90         |          r90         |          r90         |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                      |                      |          r90         |                      |          r90         |                      |          r90         |                      |          r90         |                      |                      |                      |                      |                      |          r90         |          r90         |          r90         |          r90         |          r90         |          r90         |                     ...
# +----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+-------------------- ...

# %%
inputFile = open('input.txt', 'r')
inputText = inputFile.read()
text = inputText.replace('\n', ' ')
inputFile.close()
text
# Out:
# 'She were writing a letter to Ishwarya. My teacher teaches well. She went to school. Raj is climbs a mountian. Raj plays fotball well. Mom cook delisious food. Navvya is a topper. Ishwarya is a kabbadi player. Ishwarya will sings a song in the show. These people is from Canada. Programing invloves critical thinking. It is raining since morning. The boys was playing in the garden. January is the first month of the year. They are waiting for him. They recieved the parcel yesterday. Peacocks is dancing gracefully. Goats and cows give milk. They have been waiting for his call. She has acted in two films. They have seen the movie. He draw nise portraits. They have did my homework. You have made no friends. They have never meet her husband. It has been snowing the whole week. They have paint my room recently. They have not seen him for ages. She have already written the assignment. She was listening to the last album. We have dating for weeks. They have written four emails yesterday. We have been suffering from a severe cold. My friend understand me always. We have fed the baby already. We are living in India. She has gone to specialists. Raj is going in an airplane. Ritheesh will be meeting Navvya at the airport tomorrow. It will rain in the afternoon. I will drink a cup of tea. The jacksons are having a party today. Ritheesh will be playing football tomorrow. We will have finished the room by evening. The pope is visiting Turkey in November. I will go to bed early. I will take the children to the zoo. I will climbing mountains in Switzerland. The children running down the street. Joseph has never been to a party. The building was burning in fire. Dad was feeling well. They has been waiting for me.  My grandfather has never flew in an airplane before. He is seeing a patient at the moment. The phone has been ringing constantly. People turn around every night. I were looking for a new house. I flew to America resently. We knew her whereabouts. I was repairing the car. He was taking a picture of his friend. She have been living in this neighbourhood lately We are spending the weekend in Paris. I gave a books to you. The new outlet is opening on Wednesday. We have been studying the whole evening. My brother works as an acountant. Ajitesh had saw the accident. The girls were playing backetball today.'

# %%
outputLines = []
outputLines.append("ANALYSIS REPORT : \n\n")
outputLines.append("---------------------------------------------\n\n")

# %%
# SENTENCE TOKENIZATION

stop_Char=["!",".","?",";"]

sentences=[]

sentence=""
for ch in text :
  if ch not in stop_Char:
    sentence += ch
  else :
    sentence = sentence.strip()
    sentences.append(sentence)
    sentence=""

sentenceCount = len(sentences)
print("Sentence count : " + str(sentenceCount))

for sentence in sentences :
  print(sentence)
# Out:
# Sentence count : 69
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada
# Programing invloves critical thinking
# It is raining since morning
# The boys was playing in the garden
# January is the first month of the year
# They are waiting for him
# They recieved the parcel yesterday
# Peacocks is dancing gracefully
# Goats and cows give milk
# They have been waiting for his call
# She has acted in two films
# They have seen the movie
# He draw nise portraits
# They have did my homework
# You have made no friends
# They have never meet her husband
# It has been snowing the whole week
# They have paint my room recently
# They have not seen him for ages
# She have already written the assignment
# She was listening to the last album
# We have dating for weeks
# They have written four emails yesterday
# We have been suffering from a severe cold
# My friend understand me always
# We have fed the baby already
# We are living in India
# She has gone to specialists
# Raj is going in an airplane
# Ritheesh will be meeting Navvya at the airport tomorrow
# It will rain in the afternoon
# I will drink a cup of tea
# The jacksons are having a party today
# Ritheesh will be playing football tomorrow
# We will have finished the room by evening
# The pope is visiting Turkey in November
# I will go to bed early
# I will take the children to the zoo
# I will climbing mountains in Switzerland
# The children running down the street
# Joseph has never been to a party
# The building was burning in fire
# Dad was feeling well
# They has been waiting for me
# My grandfather has never flew in an airplane before
# He is seeing a patient at the moment
# The phone has been ringing constantly
# People turn around every night
# I were looking for a new house
# I flew to America resently
# We knew her whereabouts
# I was repairing the car
# He was taking a picture of his friend
# She have been living in this neighbourhood lately We are spending the weekend in Paris
# I gave a books to you
# The new outlet is opening on Wednesday
# We have been studying the whole evening
# My brother works as an acountant
# Ajitesh had saw the accident
# The girls were playing backetball today

# %%
reqSplChars = ["@", "&", "(", ")", "-"]
splChars = ["#", "%", "&", "^", "$", "*", "`", "+"]
punctuation = [",", ".", "!"]

exclude = splChars + punctuation
cleanSentences=[]
for sentence in sentences :
  cleantext=""
  for ch in sentence :
    if ch not in exclude:
      cleantext += ch
  cleanSentences.append(cleantext)

for cleanSentence in cleanSentences :
  print(cleanSentence)
# Out:
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada
# Programing invloves critical thinking
# It is raining since morning
# The boys was playing in the garden
# January is the first month of the year
# They are waiting for him
# They recieved the parcel yesterday
# Peacocks is dancing gracefully
# Goats and cows give milk
# They have been waiting for his call
# She has acted in two films
# They have seen the movie
# He draw nise portraits
# They have did my homework
# You have made no friends
# They have never meet her husband
# It has been snowing the whole week
# They have paint my room recently
# They have not seen him for ages
# She have already written the assignment
# She was listening to the last album
# We have dating for weeks
# They have written four emails yesterday
# We have been suffering from a severe cold
# My friend understand me always
# We have fed the baby already
# We are living in India
# She has gone to specialists
# Raj is going in an airplane
# Ritheesh will be meeting Navvya at the airport tomorrow
# It will rain in the afternoon
# I will drink a cup of tea
# The jacksons are having a party today
# Ritheesh will be playing football tomorrow
# We will have finished the room by evening
# The pope is visiting Turkey in November
# I will go to bed early
# I will take the children to the zoo
# I will climbing mountains in Switzerland
# The children running down the street
# Joseph has never been to a party
# The building was burning in fire
# Dad was feeling well
# They has been waiting for me
# My grandfather has never flew in an airplane before
# He is seeing a patient at the moment
# The phone has been ringing constantly
# People turn around every night
# I were looking for a new house
# I flew to America resently
# We knew her whereabouts
# I was repairing the car
# He was taking a picture of his friend
# She have been living in this neighbourhood lately We are spending the weekend in Paris
# I gave a books to you
# The new outlet is opening on Wednesday
# We have been studying the whole evening
# My brother works as an acountant
# Ajitesh had saw the accident
# The girls were playing backetball today

# %%
# WORD TOKENIZATION

wordsArray = []
wordsCount = []
for cleanText in cleanSentences :
  words = []
  word = ""
  i = 0
  while(i < len(cleanText)):
    if(cleanText[i] == " "):
      i += 1
    else:
      word = ""
      while(i < len(cleanText) and cleanText[i] != " "):
        word += cleanText[i]
        i += 1
      if(len(word) > 0):
        words.append(word)
  wordsArray.append(words)
  wordsCount.append(len(words))

totalWordCount = sum(wordsCount)

for i in range(sentenceCount) :
  print(wordsArray[i])
  print("Word count : " + str(wordsCount[i]))
  print()
print("Total word count : " + str(totalWordCount))
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Word count : 7
#
# ['My', 'teacher', 'teaches', 'well']
# Word count : 4
#
# ['She', 'went', 'to', 'school']
# Word count : 4
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word count : 5
#
# ['Raj', 'plays', 'fotball', 'well']
# Word count : 4
#
# ['Mom', 'cook', 'delisious', 'food']
# Word count : 4
#
# ['Navvya', 'is', 'a', 'topper']
# Word count : 4
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word count : 5
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Word count : 8
#
# ['These', 'people', 'is', 'from', 'Canada']
# Word count : 5
#
# ['Programing', 'invloves', 'critical', 'thinking']
# Word count : 4
#
# ['It', 'is', 'raining', 'since', 'morning']
# Word count : 5
#
# ['The', 'boys', 'was', 'playing', 'in', 'the', 'garden']
# Word count : 7
#
# ['January', 'is', 'the', 'first', 'month', 'of', 'the', 'year']
# Word count : 8
#
# ['They', 'are', 'waiting', 'for', 'him']
# Word count : 5
#
# ['They', 'recieved', 'the', 'parcel', 'yesterday']
# Word count : 5
#
# ['Peacocks', 'is', 'dancing', 'gracefully']
# Word count : 4
#
# ['Goats', 'and', 'cows', 'give', 'milk']
# Word count : 5
#
# ['They', 'have', 'been', 'waiting', 'for', 'his', 'call']
# Word count : 7
#
# ['She', 'has', 'acted', 'in', 'two', 'films']
# Word count : 6
#
# ['They', 'have', 'seen', 'the', 'movie']
# Word count : 5
#
# ['He', 'draw', 'nise', 'portraits']
# Word count : 4
#
# ['They', 'have', 'did', 'my', 'homework']
# Word count : 5
#
# ['You', 'have', 'made', 'no', 'friends']
# Word count : 5
#
# ['They', 'have', 'never', 'meet', 'her', 'husband']
# Word count : 6
#
# ['It', 'has', 'been', 'snowing', 'the', 'whole', 'week']
# Word count : 7
#
# ['They', 'have', 'paint', 'my', 'room', 'recently']
# Word count : 6
#
# ['They', 'have', 'not', 'seen', 'him', 'for', 'ages']
# Word count : 7
#
# ['She', 'have', 'already', 'written', 'the', 'assignment']
# Word count : 6
#
# ['She', 'was', 'listening', 'to', 'the', 'last', 'album']
# Word count : 7
#
# ['We', 'have', 'dating', 'for', 'weeks']
# Word count : 5
#
# ['They', 'have', 'written', 'four', 'emails', 'yesterday']
# Word count : 6
#
# ['We', 'have', 'been', 'suffering', 'from', 'a', 'severe', 'cold']
# Word count : 8
#
# ['My', 'friend', 'understand', 'me', 'always']
# Word count : 5
#
# ['We', 'have', 'fed', 'the', 'baby', 'already']
# Word count : 6
#
# ['We', 'are', 'living', 'in', 'India']
# Word count : 5
#
# ['She', 'has', 'gone', 'to', 'specialists']
# Word count : 5
#
# ['Raj', 'is', 'going', 'in', 'an', 'airplane']
# Word count : 6
#
# ['Ritheesh', 'will', 'be', 'meeting', 'Navvya', 'at', 'the', 'airport', 'tomorrow']
# Word count : 9
#
# ['It', 'will', 'rain', 'in', 'the', 'afternoon']
# Word count : 6
#
# ['I', 'will', 'drink', 'a', 'cup', 'of', 'tea']
# Word count : 7
#
# ['The', 'jacksons', 'are', 'having', 'a', 'party', 'today']
# Word count : 7
#
# ['Ritheesh', 'will', 'be', 'playing', 'football', 'tomorrow']
# Word count : 6
#
# ['We', 'will', 'have', 'finished', 'the', 'room', 'by', 'evening']
# Word count : 8
#
# ['The', 'pope', 'is', 'visiting', 'Turkey', 'in', 'November']
# Word count : 7
#
# ['I', 'will', 'go', 'to', 'bed', 'early']
# Word count : 6
#
# ['I', 'will', 'take', 'the', 'children', 'to', 'the', 'zoo']
# Word count : 8
#
# ['I', 'will', 'climbing', 'mountains', 'in', 'Switzerland']
# Word count : 6
#
# ['The', 'children', 'running', 'down', 'the', 'street']
# Word count : 6
#
# ['Joseph', 'has', 'never', 'been', 'to', 'a', 'party']
# Word count : 7
#
# ['The', 'building', 'was', 'burning', 'in', 'fire']
# Word count : 6
#
# ['Dad', 'was', 'feeling', 'well']
# Word count : 4
#
# ['They', 'has', 'been', 'waiting', 'for', 'me']
# Word count : 6
#
# ['My', 'grandfather', 'has', 'never', 'flew', 'in', 'an', 'airplane', 'before']
# Word count : 9
#
# ['He', 'is', 'seeing', 'a', 'patient', 'at', 'the', 'moment']
# Word count : 8
#
# ['The', 'phone', 'has', 'been', 'ringing', 'constantly']
# Word count : 6
#
# ['People', 'turn', 'around', 'every', 'night']
# Word count : 5
#
# ['I', 'were', 'looking', 'for', 'a', 'new', 'house']
# Word count : 7
#
# ['I', 'flew', 'to', 'America', 'resently']
# Word count : 5
#
# ['We', 'knew', 'her', 'whereabouts']
# Word count : 4
#
# ['I', 'was', 'repairing', 'the', 'car']
# Word count : 5
#
# ['He', 'was', 'taking', 'a', 'picture', 'of', 'his', 'friend']
# Word count : 8
#
# ['She', 'have', 'been', 'living', 'in', 'this', 'neighbourhood', 'lately', 'We', 'are', 'spending', 'the', 'weekend', 'in', 'Paris']
# Word count : 15
#
# ['I', 'gave', 'a', 'books', 'to', 'you']
# Word count : 6
#
# ['The', 'new', 'outlet', 'is', 'opening', 'on', 'Wednesday']
# Word count : 7
#
# ['We', 'have', 'been', 'studying', 'the', 'whole', 'evening']
# Word count : 7
#
# ['My', 'brother', 'works', 'as', 'an', 'acountant']
# Word count : 6
#
# ['Ajitesh', 'had', 'saw', 'the', 'accident']
# Word count : 5
#
# ['The', 'girls', 'were', 'playing', 'backetball', 'today']
# Word count : 6
#
# Total word count : 418

# %%
# Spell Check
spell = SpellChecker()
correctedWordsArray = []
misspelledCount = []
misspelledResult = []
for words in wordsArray :
  count = 0
  misspelled = spell.unknown(words)

  if(len(misspelled) > 0):
    print(words)
    for word in misspelled:
        if(word not in properNouns) :
          count += 1
          print("Word : " + word)
          print("Best match : " + str(spell.correction(word)))
          print("Possible matches : " + str(spell.candidates(word)))
          misspelledResult.append("Misspelled word : {}\nBest match : {}\nPossible matches : {}\n\n".format(word, str(spell.correction(word)), str(spell.candidates(word))))
    print("Misspelled word count : " + str(count))
    misspelledCount.append(count)
    print()

    # Correcting the misspelled words
    correctedWords = []
    for word in words :
      if word in misspelled :
        correctedWords.append((spell.correction(word)).lower())
      else :
        correctedWords.append(word.lower())
    correctedWordsArray.append(correctedWords)
  else :
    correctedWords = [word.lower() for word in words]
    correctedWordsArray.append(correctedWords)
    print(words)
    print("Misspelled word count : " + str(len(misspelled)))
    print()
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Misspelled word count : 0
#
# ['My', 'teacher', 'teaches', 'well']
# Misspelled word count : 0
#
# ['She', 'went', 'to', 'school']
# Misspelled word count : 0
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word : mountian
# Best match : mountain
# Possible matches : {'mountain'}
# Misspelled word count : 1
#
# ['Raj', 'plays', 'fotball', 'well']
# Word : fotball
# Best match : football
# Possible matches : {'football'}
# Misspelled word count : 1
#
# ['Mom', 'cook', 'delisious', 'food']
# Word : delisious
# Best match : delicious
# Possible matches : {'delicious', 'delirious'}
# Misspelled word count : 1
#
# ['Navvya', 'is', 'a', 'topper']
# Misspelled word count : 0
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word : kabbadi
# Best match : kabbala
# Possible matches : {'kabbala'}
# Misspelled word count : 1
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Misspelled word count : 0
#
# ['These', 'people', 'is', 'from', 'Canada']
# Misspelled word count : 0
#
# ['Programing', 'invloves', 'critical', 'thinking']
# Word : invloves
# Best match : involves
# Possible matches : {'involves'}
# Misspelled word count : 1
#
# ['It', 'is', 'raining', 'since', 'morning']
# Misspelled word count : 0
#
# ['The', 'boys', 'was', 'playing', 'in', 'the', 'garden']
# Misspelled word count : 0
#
# ['January', 'is', 'the', 'first', 'month', 'of', 'the', 'year']
# Misspelled word count : 0
#
# ['They', 'are', 'waiting', 'for', 'him']
# Misspelled word count : 0
#
# ['They', 'recieved', 'the', 'parcel', 'yesterday']
# Word : recieved
# Best match : received
# Possible matches : {'received', 'relieved'}
# Misspelled word count : 1
#
# ['Peacocks', 'is', 'dancing', 'gracefully']
# Misspelled word count : 0
#
# ['Goats', 'and', 'cows', 'give', 'milk']
# Misspelled word count : 0
#
# ['They', 'have', 'been', 'waiting', 'for', 'his', 'call']
# Misspelled word count : 0
#
# ['She', 'has', 'acted', 'in', 'two', 'films']
# Misspelled word count : 0
#
# ['They', 'have', 'seen', 'the', 'movie']
# Misspelled word count : 0
#
# ['He', 'draw', 'nise', 'portraits']
# Word : nise
# Best match : nice
# Possible matches : {'nisei', 'nine', 'oise', 'rise', 'nice', 'noise', 'nike', 'anise', 'wise', 'nile', 'vise', 'nisi', 'nide', 'niue', 'nose', 'nite'}
# Misspelled word count : 1
#
# ['They', 'have', 'did', 'my', 'homework']
# Misspelled word count : 0
#
# ['You', 'have', 'made', 'no', 'friends']
# Misspelled word count : 0
#
# ['They', 'have', 'never', 'meet', 'her', 'husband']
# Misspelled word count : 0
#
# ['It', 'has', 'been', 'snowing', 'the', 'whole', 'week']
# Misspelled word count : 0
#
# ['They', 'have', 'paint', 'my', 'room', 'recently']
# Misspelled word count : 0
#
# ['They', 'have', 'not', 'seen', 'him', 'for', 'ages']
# Misspelled word count : 0
#
# ['She', 'have', 'already', 'written', 'the', 'assignment']
# Misspelled word count : 0
#
# ['She', 'was', 'listening', 'to', 'the', 'last', 'album']
# Misspelled word count : 0
#
# ['We', 'have', 'dating', 'for', 'weeks']
# Misspelled word count : 0
#
# ['They', 'have', 'written', 'four', 'emails', 'yesterday']
# Misspelled word count : 0
#
# ['We', 'have', 'been', 'suffering', 'from', 'a', 'severe', 'cold']
# Misspelled word count : 0
#
# ['My', 'friend', 'understand', 'me', 'always']
# Misspelled word count : 0
#
# ['We', 'have', 'fed', 'the', 'baby', 'already']
# Misspelled word count : 0
#
# ['We', 'are', 'living', 'in', 'India']
# Misspelled word count : 0
#
# ['She', 'has', 'gone', 'to', 'specialists']
# Misspelled word count : 0
#
# ['Raj', 'is', 'going', 'in', 'an', 'airplane']
# Misspelled word count : 0
#
# ['Ritheesh', 'will', 'be', 'meeting', 'Navvya', 'at', 'the', 'airport', 'tomorrow']
# Misspelled word count : 0
#
# ['It', 'will', 'rain', 'in', 'the', 'afternoon']
# Misspelled word count : 0
#
# ['I', 'will', 'drink', 'a', 'cup', 'of', 'tea']
# Misspelled word count : 0
#
# ['The', 'jacksons', 'are', 'having', 'a', 'party', 'today']
# Word : jacksons
# Best match : jackson
# Possible matches : {'jackson', "jackson's"}
# Misspelled word count : 1
#
# ['Ritheesh', 'will', 'be', 'playing', 'football', 'tomorrow']
# Misspelled word count : 0
#
# ['We', 'will', 'have', 'finished', 'the', 'room', 'by', 'evening']
# Misspelled word count : 0
#
# ['The', 'pope', 'is', 'visiting', 'Turkey', 'in', 'November']
# Misspelled word count : 0
#
# ['I', 'will', 'go', 'to', 'bed', 'early']
# Misspelled word count : 0
#
# ['I', 'will', 'take', 'the', 'children', 'to', 'the', 'zoo']
# Misspelled word count : 0
#
# ['I', 'will', 'climbing', 'mountains', 'in', 'Switzerland']
# Misspelled word count : 0
#
# ['The', 'children', 'running', 'down', 'the', 'street']
# Misspelled word count : 0
#
# ['Joseph', 'has', 'never', 'been', 'to', 'a', 'party']
# Misspelled word count : 0
#
# ['The', 'building', 'was', 'burning', 'in', 'fire']
# Misspelled word count : 0
#
# ['Dad', 'was', 'feeling', 'well']
# Misspelled word count : 0
#
# ['They', 'has', 'been', 'waiting', 'for', 'me']
# Misspelled word count : 0
#
# ['My', 'grandfather', 'has', 'never', 'flew', 'in', 'an', 'airplane', 'before']
# Misspelled word count : 0
#
# ['He', 'is', 'seeing', 'a', 'patient', 'at', 'the', 'moment']
# Misspelled word count : 0
#
# ['The', 'phone', 'has', 'been', 'ringing', 'constantly']
# Misspelled word count : 0
#
# ['People', 'turn', 'around', 'every', 'night']
# Misspelled word count : 0
#
# ['I', 'were', 'looking', 'for', 'a', 'new', 'house']
# Misspelled word count : 0
#
# ['I', 'flew', 'to', 'America', 'resently']
# Word : resently
# Best match : recently
# Possible matches : {'recently', 'presently'}
# Misspelled word count : 1
#
# ['We', 'knew', 'her', 'whereabouts']
# Misspelled word count : 0
#
# ['I', 'was', 'repairing', 'the', 'car']
# Misspelled word count : 0
#
# ['He', 'was', 'taking', 'a', 'picture', 'of', 'his', 'friend']
# Misspelled word count : 0
#
# ['She', 'have', 'been', 'living', 'in', 'this', 'neighbourhood', 'lately', 'We', 'are', 'spending', 'the', 'weekend', 'in', 'Paris']
# Word : neighbourhood
# Best match : neighborhood
# Possible matches : {'neighborhood'}
# Misspelled word count : 1
#
# ['I', 'gave', 'a', 'books', 'to', 'you']
# Misspelled word count : 0
#
# ['The', 'new', 'outlet', 'is', 'opening', 'on', 'Wednesday']
# Misspelled word count : 0
#
# ['We', 'have', 'been', 'studying', 'the', 'whole', 'evening']
# Misspelled word count : 0
#
# ['My', 'brother', 'works', 'as', 'an', 'acountant']
# Word : acountant
# Best match : accountant
# Possible matches : {'accountant'}
# Misspelled word count : 1
#
# ['Ajitesh', 'had', 'saw', 'the', 'accident']
# Misspelled word count : 0
#
# ['The', 'girls', 'were', 'playing', 'backetball', 'today']
# Word : backetball
# Best match : basketball
# Possible matches : {'racketball', 'basketball'}
# Misspelled word count : 1

# %%
totalMispelledCount = sum(misspelledCount)
print("Total misspelled words : " + str(totalMispelledCount))

print("Array of words with correct spelling : ")
for words in correctedWordsArray :
  print(words)
# Out:
# Total misspelled words : 12
# Array of words with correct spelling :
# ['she', 'were', 'writing', 'a', 'letter', 'to', 'ishwarya']
# ['my', 'teacher', 'teaches', 'well']
# ['she', 'went', 'to', 'school']
# ['raj', 'is', 'climbs', 'a', 'mountain']
# ['raj', 'plays', 'football', 'well']
# ['mom', 'cook', 'delicious', 'food']
# ['navvya', 'is', 'a', 'topper']
# ['ishwarya', 'is', 'a', 'kabbala', 'player']
# ['ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# ['these', 'people', 'is', 'from', 'canada']
# ['programing', 'involves', 'critical', 'thinking']
# ['it', 'is', 'raining', 'since', 'morning']
# ['the', 'boys', 'was', 'playing', 'in', 'the', 'garden']
# ['january', 'is', 'the', 'first', 'month', 'of', 'the', 'year']
# ['they', 'are', 'waiting', 'for', 'him']
# ['they', 'received', 'the', 'parcel', 'yesterday']
# ['peacocks', 'is', 'dancing', 'gracefully']
# ['goats', 'and', 'cows', 'give', 'milk']
# ['they', 'have', 'been', 'waiting', 'for', 'his', 'call']
# ['she', 'has', 'acted', 'in', 'two', 'films']
# ['they', 'have', 'seen', 'the', 'movie']
# ['he', 'draw', 'nice', 'portraits']
# ['they', 'have', 'did', 'my', 'homework']
# ['you', 'have', 'made', 'no', 'friends']
# ['they', 'have', 'never', 'meet', 'her', 'husband']
# ['it', 'has', 'been', 'snowing', 'the', 'whole', 'week']
# ['they', 'have', 'paint', 'my', 'room', 'recently']
# ['they', 'have', 'not', 'seen', 'him', 'for', 'ages']
# ['she', 'have', 'already', 'written', 'the', 'assignment']
# ['she', 'was', 'listening', 'to', 'the', 'last', 'album']
# ['we', 'have', 'dating', 'for', 'weeks']
# ['they', 'have', 'written', 'four', 'emails', 'yesterday']
# ['we', 'have', 'been', 'suffering', 'from', 'a', 'severe', 'cold']
# ['my', 'friend', 'understand', 'me', 'always']
# ['we', 'have', 'fed', 'the', 'baby', 'already']
# ['we', 'are', 'living', 'in', 'india']
# ['she', 'has', 'gone', 'to', 'specialists']
# ['raj', 'is', 'going', 'in', 'an', 'airplane']
# ['ritheesh', 'will', 'be', 'meeting', 'navvya', 'at', 'the', 'airport', 'tomorrow']
# ['it', 'will', 'rain', 'in', 'the', 'afternoon']
# ['i', 'will', 'drink', 'a', 'cup', 'of', 'tea']
# ['the', 'jackson', 'are', 'having', 'a', 'party', 'today']
# ['ritheesh', 'will', 'be', 'playing', 'football', 'tomorrow']
# ['we', 'will', 'have', 'finished', 'the', 'room', 'by', 'evening']
# ['the', 'pope', 'is', 'visiting', 'turkey', 'in', 'november']
# ['i', 'will', 'go', 'to', 'bed', 'early']
# ['i', 'will', 'take', 'the', 'children', 'to', 'the', 'zoo']
# ['i', 'will', 'climbing', 'mountains', 'in', 'switzerland']
# ['the', 'children', 'running', 'down', 'the', 'street']
# ['joseph', 'has', 'never', 'been', 'to', 'a', 'party']
# ['the', 'building', 'was', 'burning', 'in', 'fire']
# ['dad', 'was', 'feeling', 'well']
# ['they', 'has', 'been', 'waiting', 'for', 'me']
# ['my', 'grandfather', 'has', 'never', 'flew', 'in', 'an', 'airplane', 'before']
# ['he', 'is', 'seeing', 'a', 'patient', 'at', 'the', 'moment']
# ['the', 'phone', 'has', 'been', 'ringing', 'constantly']
# ['people', 'turn', 'around', 'every', 'night']
# ['i', 'were', 'looking', 'for', 'a', 'new', 'house']
# ['i', 'flew', 'to', 'america', 'recently']
# ['we', 'knew', 'her', 'whereabouts']
# ['i', 'was', 'repairing', 'the', 'car']
# ['he', 'was', 'taking', 'a', 'picture', 'of', 'his', 'friend']
# ['she', 'have', 'been', 'living', 'in', 'this', 'neighborhood', 'lately', 'we', 'are', 'spending', 'the', 'weekend', 'in', 'paris']
# ['i', 'gave', 'a', 'books', 'to', 'you']
# ['the', 'new', 'outlet', 'is', 'opening', 'on', 'wednesday']
# ['we', 'have', 'been', 'studying', 'the', 'whole', 'evening']
# ['my', 'brother', 'works', 'as', 'an', 'accountant']
# ['ajitesh', 'had', 'saw', 'the', 'accident']
# ['the', 'girls', 'were', 'playing', 'basketball', 'today']

# %%
outputLines.append("Sentence Count : {}\n".format(sentenceCount))
outputLines.append("Word Count : {}\n".format(totalWordCount))
outputLines.append("Misspelled Count : {}\n\n".format(totalMispelledCount))
outputLines.append("---------------------------------------------\n\n")
for result in misspelledResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %%
# Stack implementaion of input strings
def LR_parser(slr, w):
  isAccepted = False
  buffer = [x for x in w]
  buffer.append('$')
  pointer = 0
  a = buffer[pointer]
  stack = ['0']
  symbols = ['']
  results = {'step': [''], 'stack': ['STACK'] + stack, 'symbols': ['SYMBOLS'] + symbols, 'input': ['INPUT'], 'action': ['ACTION']}

  step = 0
  while True:
    s = int(stack[-1])
    step += 1
    results['step'].append(f'({step})')
    results['input'].append(' '.join(buffer[pointer:]))

    if a not in slr.parse_table[s]:
      results['action'].append(f'ERROR: unrecognized symbol {a}')
      isAccepted = False
      break

    elif not slr.parse_table[s][a]:
      results['action'].append('ERROR: input cannot be parsed by given grammar')
      isAccepted = False
      break

    elif '/' in slr.parse_table[s][a]:
      action = 'reduce' if slr.parse_table[s][a].count('r') > 1 else 'shift'
      results['action'].append(f'ERROR: {action}-reduce conflict at state {s}, symbol {a}')
      isAccepted = False
      break

    elif slr.parse_table[s][a].startswith('s'):
      results['action'].append('shift')
      stack.append(slr.parse_table[s][a][1:])
      symbols.append(a)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))
      pointer += 1
      a = buffer[pointer]

    elif slr.parse_table[s][a].startswith('r'):
      head, body = slr.G_indexed[int(slr.parse_table[s][a][1:])]
      results['action'].append(f'reduce by {head} -> {" ".join(body)}')

      if body != ('^',):
        stack = stack[:-len(body)]
        symbols = symbols[:-len(body)]

      stack.append(str(slr.parse_table[int(stack[-1])][head]))
      symbols.append(head)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))

    elif slr.parse_table[s][a] == 'acc':
      results['action'].append('accept')
      isAccepted = True
      break

  # Printing results
  def print_line():
    print(f'{"".join(["+" + ("-" * (max_len + 2)) for max_len in max_lens.values()])}+')

  max_lens = {key: max(len(value) for value in results[key]) for key in results}
  justs = {'step': '>', 'stack': '', 'symbols': '', 'input': '>', 'action': ''}

  print_line()
  print(''.join([f'| {history[0]:^{max_len}} ' for history, max_len in zip(results.values(), max_lens.values())]) + '|')
  print_line()
  for i, step in enumerate(results['step'][:-1], 1):
    print(''.join([f'| {history[i]:{just}{max_len}} ' for history, just, max_len in zip(results.values(), justs.values(), max_lens.values())]) + '|')

  print_line()

  return isAccepted

# %%
# !pip install language_tool_python
# Out:
# Collecting language_tool_python
#   Downloading language_tool_python-2.9.2-py3-none-any.whl.metadata (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from language_tool_python) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from language_tool_python) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from language_tool_python) (5.9.5)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from language_tool_python) (0.10.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->language_tool_python) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->language_tool_python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->language_tool_python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->language_tool_python) (2025.1.31)
# Downloading language_tool_python-2.9.2-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: language_tool_python
# Successfully installed language_tool_python-2.9.2

# %%
import language_tool_python

incorrectSentenceCount = 0
incorrectSentenceResult = []

# Initialize LanguageTool for grammar checking (English)
tool = language_tool_python.LanguageTool('en-US')

for input_text in correctedWordsArray:
    isAccepted = LR_parser(slr, input_text)

    # Performing semantic analysis using NLP for grammar corrections
    if not isAccepted:
        print("Correction : ")

        # Check for grammar issues using LanguageTool
        matches = tool.check(" ".join(input_text))

        if matches:
            # If there are grammar issues, suggest corrections
            corrected_text = language_tool_python.utils.correct(" ".join(input_text), matches)
            print(corrected_text)
        else:
            # If no grammar issues are found
            corrected_text="No corrections needed."
            print("No corrections needed.")

        incorrectSentenceCount += 1
        incorrectSentenceResult.append("Incorrect sentence : {}\nCorrection : {}\n\n".format(" ".join(input_text), corrected_text))
# Out:
# Downloading LanguageTool 6.5: 100%|██████████| 248M/248M [00:04<00:00, 58.6MB/s]
# INFO:language_tool_python.download_lt:Unzipping /tmp/tmpxo8b86zd.zip to /root/.cache/language_tool_python.
# INFO:language_tool_python.download_lt:Downloaded https://www.languagetool.org/download/LanguageTool-6.5.zip to /root/.cache/language_tool_python.
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |                  INPUT                  |                     ACTION                     |
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# | (1) | 0         |             | she were writing a letter to ishwarya $ | shift                                          |
# | (2) | 0 26      |  she        |     were writing a letter to ishwarya $ | reduce by PRONOUN_SG -> she                    |
# | (3) | 0 116     |  PRONOUN_SG |     were writing a letter to ishwarya $ | reduce by NP_SG -> PRONOUN_SG                  |
# | (4) | 0 160     |  NP_SG      |     were writing a letter to ishwarya $ | shift                                          |
# | (5) | 0 160 271 |  NP_SG were |          writing a letter to ishwarya $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# Correction :
# She is writing a letter to Aishwarya
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# |      |     STACK     |       SYMBOLS       |           INPUT           |                ACTION                |
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# |  (1) | 0             |                     | my teacher teaches well $ | shift                                |
# |  (2) | 0 188         |  my                 |    teacher teaches well $ | reduce by PRONOUN_SG -> my           |
# |  (3) | 0 116         |  PRONOUN_SG         |    teacher teaches well $ | shift                                |
# |  (4) | 0 116 125     |  PRONOUN_SG teacher |            teaches well $ | reduce by NOUN_SG -> teacher         |
# |  (5) | 0 116 59      |  PRONOUN_SG NOUN_SG |            teaches well $ | reduce by NOM_SG -> NOUN_SG          |
# |  (6) | 0 116 262     |  PRONOUN_SG NOM_SG  |            teaches well $ | reduce by NP_SG -> PRONOUN_SG NOM_SG |
# |  (7) | 0 160         |  NP_SG              |            teaches well $ | shift                                |
# |  (8) | 0 160 295     |  NP_SG teaches      |                    well $ | reduce by V1_SG -> teaches           |
# |  (9) | 0 160 286     |  NP_SG V1_SG        |                    well $ | reduce by PRES_SG -> V1_SG           |
# | (10) | 0 160 290     |  NP_SG PRES_SG      |                    well $ | shift                                |
# | (11) | 0 160 290 137 |  NP_SG PRES_SG well |                         $ | reduce by ADV -> well                |
# | (12) | 0 160 290 299 |  NP_SG PRES_SG ADV  |                         $ | reduce by S1 -> ADV                  |
# | (13) | 0 160 290 406 |  NP_SG PRES_SG S1   |                         $ | reduce by S -> NP_SG PRES_SG S1      |
# | (14) | 0 55          |  S                  |                         $ | accept                               |
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# |      |       STACK       |          SYMBOLS           |        INPUT         |            ACTION             |
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# |  (1) | 0                 |                            | she went to school $ | shift                         |
# |  (2) | 0 26              |  she                       |     went to school $ | reduce by PRONOUN_SG -> she   |
# |  (3) | 0 116             |  PRONOUN_SG                |     went to school $ | reduce by NP_SG -> PRONOUN_SG |
# |  (4) | 0 160             |  NP_SG                     |     went to school $ | shift                         |
# |  (5) | 0 160 222         |  NP_SG went                |          to school $ | reduce by V2 -> went          |
# |  (6) | 0 160 228         |  NP_SG V2                  |          to school $ | reduce by PAST -> V2          |
# |  (7) | 0 160 284         |  NP_SG PAST                |          to school $ | shift                         |
# |  (8) | 0 160 284 296     |  NP_SG PAST to             |             school $ | reduce by PREPOS -> to        |
# |  (9) | 0 160 284 311     |  NP_SG PAST PREPOS         |             school $ | shift                         |
# | (10) | 0 160 284 311 53  |  NP_SG PAST PREPOS school  |                    $ | reduce by NOUN_SG -> school   |
# | (11) | 0 160 284 311 59  |  NP_SG PAST PREPOS NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG   |
# | (12) | 0 160 284 311 85  |  NP_SG PAST PREPOS NOM_SG  |                    $ | reduce by NP_SG -> NOM_SG     |
# | (13) | 0 160 284 311 411 |  NP_SG PAST PREPOS NP_SG   |                    $ | reduce by PP -> PREPOS NP_SG  |
# | (14) | 0 160 284 305     |  NP_SG PAST PP             |                    $ | reduce by NP -> PP            |
# | (15) | 0 160 284 314     |  NP_SG PAST NP             |                    $ | reduce by S1 -> NP            |
# | (16) | 0 160 284 403     |  NP_SG PAST S1             |                    $ | reduce by S -> NP_SG PAST S1  |
# | (17) | 0 55              |  S                         |                    $ | accept                        |
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |           INPUT            |                     ACTION                     |
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# | (1) | 0         |             | raj is climbs a mountain $ | shift                                          |
# | (2) | 0 127     |  raj        |     is climbs a mountain $ | reduce by PROPERNOUN -> raj                    |
# | (3) | 0 44      |  PROPERNOUN |     is climbs a mountain $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 160     |  NP_SG      |     is climbs a mountain $ | shift                                          |
# | (5) | 0 160 279 |  NP_SG is   |        climbs a mountain $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# Correction :
# Raj is climbing a mountain
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# |      |     STACK     |         SYMBOLS         |           INPUT           |             ACTION              |
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# |  (1) | 0             |                         | raj plays football well $ | shift                           |
# |  (2) | 0 127         |  raj                    |     plays football well $ | reduce by PROPERNOUN -> raj     |
# |  (3) | 0 44          |  PROPERNOUN             |     plays football well $ | reduce by NP_SG -> PROPERNOUN   |
# |  (4) | 0 160         |  NP_SG                  |     plays football well $ | shift                           |
# |  (5) | 0 160 289     |  NP_SG plays            |           football well $ | reduce by V1_SG -> plays        |
# |  (6) | 0 160 286     |  NP_SG V1_SG            |           football well $ | reduce by PRES_SG -> V1_SG      |
# |  (7) | 0 160 290     |  NP_SG PRES_SG          |           football well $ | shift                           |
# |  (8) | 0 160 290 12  |  NP_SG PRES_SG football |                    well $ | reduce by NOUN_SG -> football   |
# |  (9) | 0 160 290 59  |  NP_SG PRES_SG NOUN_SG  |                    well $ | reduce by NOM_SG -> NOUN_SG     |
# | (10) | 0 160 290 85  |  NP_SG PRES_SG NOM_SG   |                    well $ | reduce by NP_SG -> NOM_SG       |
# | (11) | 0 160 290 312 |  NP_SG PRES_SG NP_SG    |                    well $ | reduce by NP -> NP_SG           |
# | (12) | 0 160 290 314 |  NP_SG PRES_SG NP       |                    well $ | reduce by S1 -> NP              |
# | (13) | 0 160 290 406 |  NP_SG PRES_SG S1       |                    well $ | reduce by S -> NP_SG PRES_SG S1 |
# | (14) | 0 55          |  S                      |                    well $ | shift                           |
# | (15) | 0 55 137      |  S well                 |                         $ | reduce by ADV -> well           |
# | (16) | 0 55 194      |  S ADV                  |                         $ | reduce by S -> S ADV            |
# | (17) | 0 55          |  S                      |                         $ | accept                          |
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# +-----+-------+----------+---------------------------+------------------------------------------------+
# |     | STACK | SYMBOLS  |           INPUT           |                     ACTION                     |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# | (1) | 0     |          | mom cook delicious food $ | shift                                          |
# | (2) | 0 106 |  mom     |     cook delicious food $ | reduce by NOUN_SG -> mom                       |
# | (3) | 0 59  |  NOUN_SG |     cook delicious food $ | reduce by NOM_SG -> NOUN_SG                    |
# | (4) | 0 85  |  NOM_SG  |     cook delicious food $ | reduce by NP_SG -> NOM_SG                      |
# | (5) | 0 160 |  NP_SG   |     cook delicious food $ | ERROR: input cannot be parsed by given grammar |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# Correction :
# Mom cook delicious food
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# |      |      STACK       |            SYMBOLS            |        INPUT         |              ACTION              |
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# |  (1) | 0                |                               | navvya is a topper $ | shift                            |
# |  (2) | 0 165            |  navvya                       |        is a topper $ | reduce by PROPERNOUN -> navvya   |
# |  (3) | 0 44             |  PROPERNOUN                   |        is a topper $ | reduce by NP_SG -> PROPERNOUN    |
# |  (4) | 0 160            |  NP_SG                        |        is a topper $ | shift                            |
# |  (5) | 0 160 279        |  NP_SG is                     |           a topper $ | reduce by V1_SG -> is            |
# |  (6) | 0 160 286        |  NP_SG V1_SG                  |           a topper $ | reduce by PRES_SG -> V1_SG       |
# |  (7) | 0 160 290        |  NP_SG PRES_SG                |           a topper $ | shift                            |
# |  (8) | 0 160 290 21     |  NP_SG PRES_SG a              |             topper $ | reduce by DET_SG -> a            |
# |  (9) | 0 160 290 92     |  NP_SG PRES_SG DET_SG         |             topper $ | shift                            |
# | (10) | 0 160 290 92 81  |  NP_SG PRES_SG DET_SG topper  |                    $ | reduce by NOUN_SG -> topper      |
# | (11) | 0 160 290 92 59  |  NP_SG PRES_SG DET_SG NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG      |
# | (12) | 0 160 290 92 204 |  NP_SG PRES_SG DET_SG NOM_SG  |                    $ | reduce by NP_SG -> DET_SG NOM_SG |
# | (13) | 0 160 290 312    |  NP_SG PRES_SG NP_SG          |                    $ | reduce by NP -> NP_SG            |
# | (14) | 0 160 290 314    |  NP_SG PRES_SG NP             |                    $ | reduce by S1 -> NP               |
# | (15) | 0 160 290 406    |  NP_SG PRES_SG S1             |                    $ | reduce by S -> NP_SG PRES_SG S1  |
# | (16) | 0 55             |  S                            |                    $ | accept                           |
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# +-----+--------------+------------------+--------------------------------+------------------------------------+
# |     |    STACK     |     SYMBOLS      |             INPUT              |               ACTION               |
# +-----+--------------+------------------+--------------------------------+------------------------------------+
# | (1) | 0            |                  | ishwarya is a kabbala player $ | shift                              |
# | (2) | 0 50         |  ishwarya        |          is a kabbala player $ | reduce by PROPERNOUN -> ishwarya   |
# | (3) | 0 44         |  PROPERNOUN      |          is a kabbala player $ | reduce by NP_SG -> PROPERNOUN      |
# | (4) | 0 160        |  NP_SG           |          is a kabbala player $ | shift                              |
# | (5) | 0 160 279    |  NP_SG is        |             a kabbala player $ | reduce by V1_SG -> is              |
# | (6) | 0 160 286    |  NP_SG V1_SG     |             a kabbala player $ | reduce by PRES_SG -> V1_SG         |
# | (7) | 0 160 290    |  NP_SG PRES_SG   |             a kabbala player $ | shift                              |
# | (8) | 0 160 290 21 |  NP_SG PRES_SG a |               kabbala player $ | ERROR: unrecognized symbol kabbala |
# +-----+--------------+------------------+--------------------------------+------------------------------------+
# Correction :
# Ishwarya is a kabbalah player
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |                  INPUT                   |                     ACTION                     |
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# | (1) | 0         |             | ishwarya will sings a song in the show $ | shift                                          |
# | (2) | 0 50      |  ishwarya   |          will sings a song in the show $ | reduce by PROPERNOUN -> ishwarya               |
# | (3) | 0 44      |  PROPERNOUN |          will sings a song in the show $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 160     |  NP_SG      |          will sings a song in the show $ | shift                                          |
# | (5) | 0 160 226 |  NP_SG will |               sings a song in the show $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# Correction :
# Ishwarya will sing a song in the show
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# |     |  STACK   |     SYMBOLS     |             INPUT             |                     ACTION                     |
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# | (1) | 0        |                 | these people is from canada $ | shift                                          |
# | (2) | 0 101    |  these          |       people is from canada $ | reduce by DET_PL -> these                      |
# | (3) | 0 20     |  DET_PL         |       people is from canada $ | shift                                          |
# | (4) | 0 20 132 |  DET_PL people  |              is from canada $ | reduce by NOUN_PL -> people                    |
# | (5) | 0 20 173 |  DET_PL NOUN_PL |              is from canada $ | reduce by NOM_PL -> NOUN_PL                    |
# | (6) | 0 20 191 |  DET_PL NOM_PL  |              is from canada $ | reduce by NP_PL -> DET_PL NOM_PL               |
# | (7) | 0 100    |  NP_PL          |              is from canada $ | ERROR: input cannot be parsed by given grammar |
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# Correction :
# These people are from Canada
# +-----+-------+---------+-----------------------------------------+---------------------------------------+
# |     | STACK | SYMBOLS |                  INPUT                  |                ACTION                 |
# +-----+-------+---------+-----------------------------------------+---------------------------------------+
# | (1) | 0     |         | programing involves critical thinking $ | ERROR: unrecognized symbol programing |
# +-----+-------+---------+-----------------------------------------+---------------------------------------+
# Correction :
# Programing involves critical thinking
# +------+------------------+---------------------------------+-------------------------------+--------------------------------------+
# |      |      STACK       |             SYMBOLS             |             INPUT             |                ACTION                |
# +------+------------------+---------------------------------+-------------------------------+--------------------------------------+
# |  (1) | 0                |                                 | it is raining since morning $ | shift                                |
# |  (2) | 0 147            |  it                             |    is raining since morning $ | reduce by PRONOUN_SG -> it           |
# |  (3) | 0 116            |  PRONOUN_SG                     |    is raining since morning $ | reduce by NP_SG -> PRONOUN_SG        |
# |  (4) | 0 160            |  NP_SG                          |    is raining since morning $ | shift                                |
# |  (5) | 0 160 279        |  NP_SG is                       |       raining since morning $ | shift                                |
# |  (6) | 0 160 279 321    |  NP_SG is raining               |               since morning $ | reduce by GERUNDV -> raining         |
# |  (7) | 0 160 279 402    |  NP_SG is GERUNDV               |               since morning $ | reduce by PRES_CONT_SG -> is GERUNDV |
# |  (8) | 0 160 288        |  NP_SG PRES_CONT_SG             |               since morning $ | shift                                |
# |  (9) | 0 160 288 159    |  NP_SG PRES_CONT_SG since       |                     morning $ | reduce by ADJ -> since               |
# | (10) | 0 160 288 41     |  NP_SG PRES_CONT_SG ADJ         |                     morning $ | shift                                |
# | (11) | 0 160 288 41 9   |  NP_SG PRES_CONT_SG ADJ morning |                             $ | reduce by NOUN_SG -> morning         |
# | (12) | 0 160 288 41 192 |  NP_SG PRES_CONT_SG ADJ NOUN_SG |                             $ | reduce by NOM_SG -> ADJ NOUN_SG      |
# | (13) | 0 160 288 85     |  NP_SG PRES_CONT_SG NOM_SG      |                             $ | reduce by NP_SG -> NOM_SG            |
# | (14) | 0 160 288 312    |  NP_SG PRES_CONT_SG NP_SG       |                             $ | reduce by NP -> NP_SG                |
# | (15) | 0 160 288 314    |  NP_SG PRES_CONT_SG NP          |                             $ | reduce by S1 -> NP                   |
# | (16) | 0 160 288 405    |  NP_SG PRES_CONT_SG S1          |                             $ | reduce by S -> NP_SG PRES_CONT_SG S1 |
# | (17) | 0 55             |  S                              |                             $ | accept                               |
# +------+------------------+---------------------------------+-------------------------------+--------------------------------------+
# +-----+-----------+-------------------+--------------------------------------+------------------------------------------------+
# |     |   STACK   |      SYMBOLS      |                INPUT                 |                     ACTION                     |
# +-----+-----------+-------------------+--------------------------------------+------------------------------------------------+
# | (1) | 0         |                   | the boys was playing in the garden $ | shift                                          |
# | (2) | 0 161     |  the              |     boys was playing in the garden $ | reduce by DET_BOTH -> the                      |
# | (3) | 0 61      |  DET_BOTH         |     boys was playing in the garden $ | shift                                          |
# | (4) | 0 61 99   |  DET_BOTH boys    |          was playing in the garden $ | reduce by NOUN_PL -> boys                      |
# | (5) | 0 61 173  |  DET_BOTH NOUN_PL |          was playing in the garden $ | reduce by NOM_PL -> NOUN_PL                    |
# | (6) | 0 61 199  |  DET_BOTH NOM_PL  |          was playing in the garden $ | reduce by NP_PL -> DET_BOTH NOM_PL             |
# | (7) | 0 100     |  NP_PL            |          was playing in the garden $ | shift                                          |
# | (8) | 0 100 213 |  NP_PL was        |              playing in the garden $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------------+--------------------------------------+------------------------------------------------+
# Correction :
# The boys were playing in the garden
# +------+--------------------------+-------------------------------------------+------------------------------------------+------------------------------------+
# |      |          STACK           |                  SYMBOLS                  |                  INPUT                   |               ACTION               |
# +------+--------------------------+-------------------------------------------+------------------------------------------+------------------------------------+
# |  (1) | 0                        |                                           | january is the first month of the year $ | shift                              |
# |  (2) | 0 31                     |  january                                  |         is the first month of the year $ | reduce by PROPERNOUN -> january    |
# |  (3) | 0 44                     |  PROPERNOUN                               |         is the first month of the year $ | reduce by NP_SG -> PROPERNOUN      |
# |  (4) | 0 160                    |  NP_SG                                    |         is the first month of the year $ | shift                              |
# |  (5) | 0 160 279                |  NP_SG is                                 |            the first month of the year $ | reduce by V1_SG -> is              |
# |  (6) | 0 160 286                |  NP_SG V1_SG                              |            the first month of the year $ | reduce by PRES_SG -> V1_SG         |
# |  (7) | 0 160 290                |  NP_SG PRES_SG                            |            the first month of the year $ | shift                              |
# |  (8) | 0 160 290 161            |  NP_SG PRES_SG the                        |                first month of the year $ | reduce by DET_BOTH -> the          |
# |  (9) | 0 160 290 61             |  NP_SG PRES_SG DET_BOTH                   |                first month of the year $ | shift                              |
# | (10) | 0 160 290 61 25          |  NP_SG PRES_SG DET_BOTH first             |                      month of the year $ | reduce by ADJ -> first             |
# | (11) | 0 160 290 61 41          |  NP_SG PRES_SG DET_BOTH ADJ               |                      month of the year $ | shift                              |
# | (12) | 0 160 290 61 41 35       |  NP_SG PRES_SG DET_BOTH ADJ month         |                            of the year $ | reduce by NOUN_SG -> month         |
# | (13) | 0 160 290 61 41 192      |  NP_SG PRES_SG DET_BOTH ADJ NOUN_SG       |                            of the year $ | reduce by NOM_SG -> ADJ NOUN_SG    |
# | (14) | 0 160 290 61 200         |  NP_SG PRES_SG DET_BOTH NOM_SG            |                            of the year $ | reduce by NP_SG -> DET_BOTH NOM_SG |
# | (15) | 0 160 290 312            |  NP_SG PRES_SG NP_SG                      |                            of the year $ | reduce by NP -> NP_SG              |
# | (16) | 0 160 290 314            |  NP_SG PRES_SG NP                         |                            of the year $ | shift                              |
# | (17) | 0 160 290 314 309        |  NP_SG PRES_SG NP of                      |                               the year $ | reduce by PREPOS -> of             |
# | (18) | 0 160 290 314 311        |  NP_SG PRES_SG NP PREPOS                  |                               the year $ | shift                              |
# | (19) | 0 160 290 314 311 161    |  NP_SG PRES_SG NP PREPOS the              |                                   year $ | reduce by DET_BOTH -> the          |
# | (20) | 0 160 290 314 311 61     |  NP_SG PRES_SG NP PREPOS DET_BOTH         |                                   year $ | shift                              |
# | (21) | 0 160 290 314 311 61 33  |  NP_SG PRES_SG NP PREPOS DET_BOTH year    |                                        $ | reduce by NOUN_SG -> year          |
# | (22) | 0 160 290 314 311 61 59  |  NP_SG PRES_SG NP PREPOS DET_BOTH NOUN_SG |                                        $ | reduce by NOM_SG -> NOUN_SG        |
# | (23) | 0 160 290 314 311 61 200 |  NP_SG PRES_SG NP PREPOS DET_BOTH NOM_SG  |                                        $ | reduce by NP_SG -> DET_BOTH NOM_SG |
# | (24) | 0 160 290 314 311 411    |  NP_SG PRES_SG NP PREPOS NP_SG            |                                        $ | reduce by PP -> PREPOS NP_SG       |
# | (25) | 0 160 290 314 412        |  NP_SG PRES_SG NP PP                      |                                        $ | reduce by NP -> NP PP              |
# | (26) | 0 160 290 314            |  NP_SG PRES_SG NP                         |                                        $ | reduce by S1 -> NP                 |
# | (27) | 0 160 290 406            |  NP_SG PRES_SG S1                         |                                        $ | reduce by S -> NP_SG PRES_SG S1    |
# | (28) | 0 55                     |  S                                        |                                        $ | accept                             |
# +------+--------------------------+-------------------------------------------+------------------------------------------+------------------------------------+
# +------+-------------------+---------------------------------------+----------------------------+---------------------------------------+
# |      |       STACK       |                SYMBOLS                |           INPUT            |                ACTION                 |
# +------+-------------------+---------------------------------------+----------------------------+---------------------------------------+
# |  (1) | 0                 |                                       | they are waiting for him $ | shift                                 |
# |  (2) | 0 177             |  they                                 |      are waiting for him $ | reduce by PRONOUN_PL -> they          |
# |  (3) | 0 16              |  PRONOUN_PL                           |      are waiting for him $ | reduce by NP_PL -> PRONOUN_PL         |
# |  (4) | 0 100             |  NP_PL                                |      are waiting for him $ | shift                                 |
# |  (5) | 0 100 207         |  NP_PL are                            |          waiting for him $ | shift                                 |
# |  (6) | 0 100 207 332     |  NP_PL are waiting                    |                  for him $ | reduce by GERUNDV -> waiting          |
# |  (7) | 0 100 207 331     |  NP_PL are GERUNDV                    |                  for him $ | reduce by PRES_CONT_PL -> are GERUNDV |
# |  (8) | 0 100 256         |  NP_PL PRES_CONT_PL                   |                  for him $ | shift                                 |
# |  (9) | 0 100 256 308     |  NP_PL PRES_CONT_PL for               |                      him $ | reduce by PREPOS -> for               |
# | (10) | 0 100 256 311     |  NP_PL PRES_CONT_PL PREPOS            |                      him $ | shift                                 |
# | (11) | 0 100 256 311 19  |  NP_PL PRES_CONT_PL PREPOS him        |                          $ | reduce by PRONOUN_SG -> him           |
# | (12) | 0 100 256 311 116 |  NP_PL PRES_CONT_PL PREPOS PRONOUN_SG |                          $ | reduce by NP_SG -> PRONOUN_SG         |
# | (13) | 0 100 256 311 411 |  NP_PL PRES_CONT_PL PREPOS NP_SG      |                          $ | reduce by PP -> PREPOS NP_SG          |
# | (14) | 0 100 256 305     |  NP_PL PRES_CONT_PL PP                |                          $ | reduce by NP -> PP                    |
# | (15) | 0 100 256 314     |  NP_PL PRES_CONT_PL NP                |                          $ | reduce by S1 -> NP                    |
# | (16) | 0 100 256 387     |  NP_PL PRES_CONT_PL S1                |                          $ | reduce by S -> NP_PL PRES_CONT_PL S1  |
# | (17) | 0 55              |  S                                    |                          $ | accept                                |
# +------+-------------------+---------------------------------------+----------------------------+---------------------------------------+
# +------+------------------+------------------------------+--------------------------------------+------------------------------------+
# |      |      STACK       |           SYMBOLS            |                INPUT                 |               ACTION               |
# +------+------------------+------------------------------+--------------------------------------+------------------------------------+
# |  (1) | 0                |                              | they received the parcel yesterday $ | shift                              |
# |  (2) | 0 177            |  they                        |      received the parcel yesterday $ | reduce by PRONOUN_PL -> they       |
# |  (3) | 0 16             |  PRONOUN_PL                  |      received the parcel yesterday $ | reduce by NP_PL -> PRONOUN_PL      |
# |  (4) | 0 100            |  NP_PL                       |      received the parcel yesterday $ | shift                              |
# |  (5) | 0 100 240        |  NP_PL received              |               the parcel yesterday $ | reduce by V2 -> received           |
# |  (6) | 0 100 228        |  NP_PL V2                    |               the parcel yesterday $ | reduce by PAST -> V2               |
# |  (7) | 0 100 244        |  NP_PL PAST                  |               the parcel yesterday $ | shift                              |
# |  (8) | 0 100 244 161    |  NP_PL PAST the              |                   parcel yesterday $ | reduce by DET_BOTH -> the          |
# |  (9) | 0 100 244 61     |  NP_PL PAST DET_BOTH         |                   parcel yesterday $ | shift                              |
# | (10) | 0 100 244 61 113 |  NP_PL PAST DET_BOTH parcel  |                          yesterday $ | reduce by NOUN_SG -> parcel        |
# | (11) | 0 100 244 61 59  |  NP_PL PAST DET_BOTH NOUN_SG |                          yesterday $ | reduce by NOM_SG -> NOUN_SG        |
# | (12) | 0 100 244 61 200 |  NP_PL PAST DET_BOTH NOM_SG  |                          yesterday $ | reduce by NP_SG -> DET_BOTH NOM_SG |
# | (13) | 0 100 244 312    |  NP_PL PAST NP_SG            |                          yesterday $ | reduce by NP -> NP_SG              |
# | (14) | 0 100 244 314    |  NP_PL PAST NP               |                          yesterday $ | reduce by S1 -> NP                 |
# | (15) | 0 100 244 381    |  NP_PL PAST S1               |                          yesterday $ | reduce by S -> NP_PL PAST S1       |
# | (16) | 0 55             |  S                           |                          yesterday $ | shift                              |
# | (17) | 0 55 29          |  S yesterday                 |                                    $ | reduce by ADV -> yesterday         |
# | (18) | 0 55 194         |  S ADV                       |                                    $ | reduce by S -> S ADV               |
# | (19) | 0 55             |  S                           |                                    $ | accept                             |
# +------+------------------+------------------------------+--------------------------------------+------------------------------------+
# +-----+-------+-----------+----------------------------------+------------------------------------------------+
# |     | STACK |  SYMBOLS  |              INPUT               |                     ACTION                     |
# +-----+-------+-----------+----------------------------------+------------------------------------------------+
# | (1) | 0     |           | peacocks is dancing gracefully $ | shift                                          |
# | (2) | 0 129 |  peacocks |          is dancing gracefully $ | reduce by NOUN_PL -> peacocks                  |
# | (3) | 0 173 |  NOUN_PL  |          is dancing gracefully $ | reduce by NOM_PL -> NOUN_PL                    |
# | (4) | 0 66  |  NOM_PL   |          is dancing gracefully $ | reduce by NP_PL -> NOM_PL                      |
# | (5) | 0 100 |  NP_PL    |          is dancing gracefully $ | ERROR: input cannot be parsed by given grammar |
# +-----+-------+-----------+----------------------------------+------------------------------------------------+
# Correction :
# Peacocks are dancing gracefully
# +------+---------------+------------------------+----------------------------+----------------------------------+
# |      |     STACK     |        SYMBOLS         |           INPUT            |              ACTION              |
# +------+---------------+------------------------+----------------------------+----------------------------------+
# |  (1) | 0             |                        | goats and cows give milk $ | shift                            |
# |  (2) | 0 167         |  goats                 |       and cows give milk $ | reduce by NOUN_PL -> goats       |
# |  (3) | 0 173         |  NOUN_PL               |       and cows give milk $ | reduce by NOM_PL -> NOUN_PL      |
# |  (4) | 0 66          |  NOM_PL                |       and cows give milk $ | reduce by NP_PL -> NOM_PL        |
# |  (5) | 0 100         |  NP_PL                 |       and cows give milk $ | shift                            |
# |  (6) | 0 100 231     |  NP_PL and             |           cows give milk $ | reduce by CONJ -> and            |
# |  (7) | 0 100 255     |  NP_PL CONJ            |           cows give milk $ | shift                            |
# |  (8) | 0 100 255 164 |  NP_PL CONJ cows       |                give milk $ | reduce by NOUN_PL -> cows        |
# |  (9) | 0 100 255 173 |  NP_PL CONJ NOUN_PL    |                give milk $ | reduce by NOM_PL -> NOUN_PL      |
# | (10) | 0 100 255 66  |  NP_PL CONJ NOM_PL     |                give milk $ | reduce by NP_PL -> NOM_PL        |
# | (11) | 0 100 255 302 |  NP_PL CONJ NP_PL      |                give milk $ | reduce by NP -> NP_PL            |
# | (12) | 0 100 255 386 |  NP_PL CONJ NP         |                give milk $ | reduce by NP_PL -> NP_PL CONJ NP |
# | (13) | 0 100         |  NP_PL                 |                give milk $ | shift                            |
# | (14) | 0 100 236     |  NP_PL give            |                     milk $ | reduce by V1_PL -> give          |
# | (15) | 0 100 233     |  NP_PL V1_PL           |                     milk $ | reduce by PRES_PL -> V1_PL       |
# | (16) | 0 100 206     |  NP_PL PRES_PL         |                     milk $ | shift                            |
# | (17) | 0 100 206 142 |  NP_PL PRES_PL milk    |                          $ | reduce by NOUN_SG -> milk        |
# | (18) | 0 100 206 59  |  NP_PL PRES_PL NOUN_SG |                          $ | reduce by NOM_SG -> NOUN_SG      |
# | (19) | 0 100 206 85  |  NP_PL PRES_PL NOM_SG  |                          $ | reduce by NP_SG -> NOM_SG        |
# | (20) | 0 100 206 312 |  NP_PL PRES_PL NP_SG   |                          $ | reduce by NP -> NP_SG            |
# | (21) | 0 100 206 314 |  NP_PL PRES_PL NP      |                          $ | reduce by S1 -> NP               |
# | (22) | 0 100 206 315 |  NP_PL PRES_PL S1      |                          $ | reduce by S -> NP_PL PRES_PL S1  |
# | (23) | 0 55          |  S                     |                          $ | accept                           |
# +------+---------------+------------------------+----------------------------+----------------------------------+
# +------+-----------------------+-------------------------------------------------------+---------------------------------------+-----------------------------------------------------+
# |      |         STACK         |                        SYMBOLS                        |                 INPUT                 |                       ACTION                        |
# +------+-----------------------+-------------------------------------------------------+---------------------------------------+-----------------------------------------------------+
# |  (1) | 0                     |                                                       | they have been waiting for his call $ | shift                                               |
# |  (2) | 0 177                 |  they                                                 |      have been waiting for his call $ | reduce by PRONOUN_PL -> they                        |
# |  (3) | 0 16                  |  PRONOUN_PL                                           |      have been waiting for his call $ | reduce by NP_PL -> PRONOUN_PL                       |
# |  (4) | 0 100                 |  NP_PL                                                |      have been waiting for his call $ | shift                                               |
# |  (5) | 0 100 211             |  NP_PL have                                           |           been waiting for his call $ | shift                                               |
# |  (6) | 0 100 211 358         |  NP_PL have been                                      |                waiting for his call $ | shift                                               |
# |  (7) | 0 100 211 358 332     |  NP_PL have been waiting                              |                        for his call $ | reduce by GERUNDV -> waiting                        |
# |  (8) | 0 100 211 358 416     |  NP_PL have been GERUNDV                              |                        for his call $ | reduce by PRES_PERFECT_CONT_PL -> have been GERUNDV |
# |  (9) | 0 100 212             |  NP_PL PRES_PERFECT_CONT_PL                           |                        for his call $ | shift                                               |
# | (10) | 0 100 212 308         |  NP_PL PRES_PERFECT_CONT_PL for                       |                            his call $ | reduce by PREPOS -> for                             |
# | (11) | 0 100 212 311         |  NP_PL PRES_PERFECT_CONT_PL PREPOS                    |                            his call $ | shift                                               |
# | (12) | 0 100 212 311 65      |  NP_PL PRES_PERFECT_CONT_PL PREPOS his                |                                call $ | reduce by PRONOUN_SG -> his                         |
# | (13) | 0 100 212 311 116     |  NP_PL PRES_PERFECT_CONT_PL PREPOS PRONOUN_SG         |                                call $ | shift                                               |
# | (14) | 0 100 212 311 116 102 |  NP_PL PRES_PERFECT_CONT_PL PREPOS PRONOUN_SG call    |                                     $ | reduce by NOUN_SG -> call                           |
# | (15) | 0 100 212 311 116 59  |  NP_PL PRES_PERFECT_CONT_PL PREPOS PRONOUN_SG NOUN_SG |                                     $ | reduce by NOM_SG -> NOUN_SG                         |
# | (16) | 0 100 212 311 116 262 |  NP_PL PRES_PERFECT_CONT_PL PREPOS PRONOUN_SG NOM_SG  |                                     $ | reduce by NP_SG -> PRONOUN_SG NOM_SG                |
# | (17) | 0 100 212 311 411     |  NP_PL PRES_PERFECT_CONT_PL PREPOS NP_SG              |                                     $ | reduce by PP -> PREPOS NP_SG                        |
# | (18) | 0 100 212 305         |  NP_PL PRES_PERFECT_CONT_PL PP                        |                                     $ | reduce by NP -> PP                                  |
# | (19) | 0 100 212 314         |  NP_PL PRES_PERFECT_CONT_PL NP                        |                                     $ | reduce by S1 -> NP                                  |
# | (20) | 0 100 212 364         |  NP_PL PRES_PERFECT_CONT_PL S1                        |                                     $ | reduce by S -> NP_PL PRES_PERFECT_CONT_PL S1        |
# | (21) | 0 55                  |  S                                                    |                                     $ | accept                                              |
# +------+-----------------------+-------------------------------------------------------+---------------------------------------+-----------------------------------------------------+
# +------+----------------------+-------------------------------------------+------------------------------+-----------------------------------------+
# |      |        STACK         |                  SYMBOLS                  |            INPUT             |                 ACTION                  |
# +------+----------------------+-------------------------------------------+------------------------------+-----------------------------------------+
# |  (1) | 0                    |                                           | she has acted in two films $ | shift                                   |
# |  (2) | 0 26                 |  she                                      |     has acted in two films $ | reduce by PRONOUN_SG -> she             |
# |  (3) | 0 116                |  PRONOUN_SG                               |     has acted in two films $ | reduce by NP_SG -> PRONOUN_SG           |
# |  (4) | 0 160                |  NP_SG                                    |     has acted in two films $ | shift                                   |
# |  (5) | 0 160 276            |  NP_SG has                                |         acted in two films $ | shift                                   |
# |  (6) | 0 160 276 353        |  NP_SG has acted                          |               in two films $ | reduce by V3 -> acted                   |
# |  (7) | 0 160 276 399        |  NP_SG has V3                             |               in two films $ | reduce by PRES_PERFECT_SG -> has V3     |
# |  (8) | 0 160 273            |  NP_SG PRES_PERFECT_SG                    |               in two films $ | shift                                   |
# |  (9) | 0 160 273 301        |  NP_SG PRES_PERFECT_SG in                 |                  two films $ | reduce by PREPOS -> in                  |
# | (10) | 0 160 273 311        |  NP_SG PRES_PERFECT_SG PREPOS             |                  two films $ | shift                                   |
# | (11) | 0 160 273 311 135    |  NP_SG PRES_PERFECT_SG PREPOS two         |                      films $ | reduce by ADJ -> two                    |
# | (12) | 0 160 273 311 41     |  NP_SG PRES_PERFECT_SG PREPOS ADJ         |                      films $ | shift                                   |
# | (13) | 0 160 273 311 41 73  |  NP_SG PRES_PERFECT_SG PREPOS ADJ films   |                            $ | reduce by NOUN_PL -> films              |
# | (14) | 0 160 273 311 41 193 |  NP_SG PRES_PERFECT_SG PREPOS ADJ NOUN_PL |                            $ | reduce by NOM_PL -> ADJ NOUN_PL         |
# | (15) | 0 160 273 311 66     |  NP_SG PRES_PERFECT_SG PREPOS NOM_PL      |                            $ | reduce by NP_PL -> NOM_PL               |
# | (16) | 0 160 273 311 410    |  NP_SG PRES_PERFECT_SG PREPOS NP_PL       |                            $ | reduce by PP -> PREPOS NP_PL            |
# | (17) | 0 160 273 305        |  NP_SG PRES_PERFECT_SG PP                 |                            $ | reduce by NP -> PP                      |
# | (18) | 0 160 273 314        |  NP_SG PRES_PERFECT_SG NP                 |                            $ | reduce by S1 -> NP                      |
# | (19) | 0 160 273 396        |  NP_SG PRES_PERFECT_SG S1                 |                            $ | reduce by S -> NP_SG PRES_PERFECT_SG S1 |
# | (20) | 0 55                 |  S                                        |                            $ | accept                                  |
# +------+----------------------+-------------------------------------------+------------------------------+-----------------------------------------+
# +------+------------------+-----------------------------------------+----------------------------+-----------------------------------------+
# |      |      STACK       |                 SYMBOLS                 |           INPUT            |                 ACTION                  |
# +------+------------------+-----------------------------------------+----------------------------+-----------------------------------------+
# |  (1) | 0                |                                         | they have seen the movie $ | shift                                   |
# |  (2) | 0 177            |  they                                   |      have seen the movie $ | reduce by PRONOUN_PL -> they            |
# |  (3) | 0 16             |  PRONOUN_PL                             |      have seen the movie $ | reduce by NP_PL -> PRONOUN_PL           |
# |  (4) | 0 100            |  NP_PL                                  |      have seen the movie $ | shift                                   |
# |  (5) | 0 100 211        |  NP_PL have                             |           seen the movie $ | shift                                   |
# |  (6) | 0 100 211 356    |  NP_PL have seen                        |                the movie $ | reduce by V3 -> seen                    |
# |  (7) | 0 100 211 359    |  NP_PL have V3                          |                the movie $ | reduce by PRES_PERFECT_PL -> have V3    |
# |  (8) | 0 100 245        |  NP_PL PRES_PERFECT_PL                  |                the movie $ | shift                                   |
# |  (9) | 0 100 245 161    |  NP_PL PRES_PERFECT_PL the              |                    movie $ | reduce by DET_BOTH -> the               |
# | (10) | 0 100 245 61     |  NP_PL PRES_PERFECT_PL DET_BOTH         |                    movie $ | shift                                   |
# | (11) | 0 100 245 61 150 |  NP_PL PRES_PERFECT_PL DET_BOTH movie   |                          $ | reduce by NOUN_SG -> movie              |
# | (12) | 0 100 245 61 59  |  NP_PL PRES_PERFECT_PL DET_BOTH NOUN_SG |                          $ | reduce by NOM_SG -> NOUN_SG             |
# | (13) | 0 100 245 61 200 |  NP_PL PRES_PERFECT_PL DET_BOTH NOM_SG  |                          $ | reduce by NP_SG -> DET_BOTH NOM_SG      |
# | (14) | 0 100 245 312    |  NP_PL PRES_PERFECT_PL NP_SG            |                          $ | reduce by NP -> NP_SG                   |
# | (15) | 0 100 245 314    |  NP_PL PRES_PERFECT_PL NP               |                          $ | reduce by S1 -> NP                      |
# | (16) | 0 100 245 382    |  NP_PL PRES_PERFECT_PL S1               |                          $ | reduce by S -> NP_PL PRES_PERFECT_PL S1 |
# | (17) | 0 55             |  S                                      |                          $ | accept                                  |
# +------+------------------+-----------------------------------------+----------------------------+-----------------------------------------+
# ...
# |  (4) | 0 61 11           |  DET_BOTH new                         |         outlet is opening on wednesday $ | reduce by ADJ -> new                 |
# |  (5) | 0 61 41           |  DET_BOTH ADJ                         |         outlet is opening on wednesday $ | shift                                |
# |  (6) | 0 61 41 49        |  DET_BOTH ADJ outlet                  |                is opening on wednesday $ | reduce by NOUN_SG -> outlet          |
# |  (7) | 0 61 41 192       |  DET_BOTH ADJ NOUN_SG                 |                is opening on wednesday $ | reduce by NOM_SG -> ADJ NOUN_SG      |
# |  (8) | 0 61 200          |  DET_BOTH NOM_SG                      |                is opening on wednesday $ | reduce by NP_SG -> DET_BOTH NOM_SG   |
# |  (9) | 0 160             |  NP_SG                                |                is opening on wednesday $ | shift                                |
# | (10) | 0 160 279         |  NP_SG is                             |                   opening on wednesday $ | shift                                |
# | (11) | 0 160 279 346     |  NP_SG is opening                     |                           on wednesday $ | reduce by GERUNDV -> opening         |
# | (12) | 0 160 279 402     |  NP_SG is GERUNDV                     |                           on wednesday $ | reduce by PRES_CONT_SG -> is GERUNDV |
# | (13) | 0 160 288         |  NP_SG PRES_CONT_SG                   |                           on wednesday $ | shift                                |
# | (14) | 0 160 288 298     |  NP_SG PRES_CONT_SG on                |                              wednesday $ | reduce by PREPOS -> on               |
# | (15) | 0 160 288 311     |  NP_SG PRES_CONT_SG PREPOS            |                              wednesday $ | shift                                |
# | (16) | 0 160 288 311 155 |  NP_SG PRES_CONT_SG PREPOS wednesday  |                                        $ | reduce by PROPERNOUN -> wednesday    |
# | (17) | 0 160 288 311 44  |  NP_SG PRES_CONT_SG PREPOS PROPERNOUN |                                        $ | reduce by NP_SG -> PROPERNOUN        |
# | (18) | 0 160 288 311 411 |  NP_SG PRES_CONT_SG PREPOS NP_SG      |                                        $ | reduce by PP -> PREPOS NP_SG         |
# | (19) | 0 160 288 305     |  NP_SG PRES_CONT_SG PP                |                                        $ | reduce by NP -> PP                   |
# | (20) | 0 160 288 314     |  NP_SG PRES_CONT_SG NP                |                                        $ | reduce by S1 -> NP                   |
# | (21) | 0 160 288 405     |  NP_SG PRES_CONT_SG S1                |                                        $ | reduce by S -> NP_SG PRES_CONT_SG S1 |
# | (22) | 0 55              |  S                                    |                                        $ | accept                               |
# +------+-------------------+---------------------------------------+------------------------------------------+--------------------------------------+
# +------+---------------------+--------------------------------------------------+-------------------------------------------+-----------------------------------------------------+
# |      |        STACK        |                     SYMBOLS                      |                   INPUT                   |                       ACTION                        |
# +------+---------------------+--------------------------------------------------+-------------------------------------------+-----------------------------------------------------+
# |  (1) | 0                   |                                                  | we have been studying the whole evening $ | shift                                               |
# |  (2) | 0 133               |  we                                              |    have been studying the whole evening $ | reduce by PRONOUN_PL -> we                          |
# |  (3) | 0 16                |  PRONOUN_PL                                      |    have been studying the whole evening $ | reduce by NP_PL -> PRONOUN_PL                       |
# |  (4) | 0 100               |  NP_PL                                           |    have been studying the whole evening $ | shift                                               |
# |  (5) | 0 100 211           |  NP_PL have                                      |         been studying the whole evening $ | shift                                               |
# |  (6) | 0 100 211 358       |  NP_PL have been                                 |              studying the whole evening $ | shift                                               |
# |  (7) | 0 100 211 358 340   |  NP_PL have been studying                        |                       the whole evening $ | reduce by GERUNDV -> studying                       |
# |  (8) | 0 100 211 358 416   |  NP_PL have been GERUNDV                         |                       the whole evening $ | reduce by PRES_PERFECT_CONT_PL -> have been GERUNDV |
# |  (9) | 0 100 212           |  NP_PL PRES_PERFECT_CONT_PL                      |                       the whole evening $ | shift                                               |
# | (10) | 0 100 212 161       |  NP_PL PRES_PERFECT_CONT_PL the                  |                           whole evening $ | reduce by DET_BOTH -> the                           |
# | (11) | 0 100 212 61        |  NP_PL PRES_PERFECT_CONT_PL DET_BOTH             |                           whole evening $ | shift                                               |
# | (12) | 0 100 212 61 134    |  NP_PL PRES_PERFECT_CONT_PL DET_BOTH whole       |                                 evening $ | reduce by ADJ -> whole                              |
# | (13) | 0 100 212 61 41     |  NP_PL PRES_PERFECT_CONT_PL DET_BOTH ADJ         |                                 evening $ | shift                                               |
# | (14) | 0 100 212 61 41 6   |  NP_PL PRES_PERFECT_CONT_PL DET_BOTH ADJ evening |                                         $ | reduce by NOUN_SG -> evening                        |
# | (15) | 0 100 212 61 41 192 |  NP_PL PRES_PERFECT_CONT_PL DET_BOTH ADJ NOUN_SG |                                         $ | reduce by NOM_SG -> ADJ NOUN_SG                     |
# | (16) | 0 100 212 61 200    |  NP_PL PRES_PERFECT_CONT_PL DET_BOTH NOM_SG      |                                         $ | reduce by NP_SG -> DET_BOTH NOM_SG                  |
# | (17) | 0 100 212 312       |  NP_PL PRES_PERFECT_CONT_PL NP_SG                |                                         $ | reduce by NP -> NP_SG                               |
# | (18) | 0 100 212 314       |  NP_PL PRES_PERFECT_CONT_PL NP                   |                                         $ | reduce by S1 -> NP                                  |
# | (19) | 0 100 212 364       |  NP_PL PRES_PERFECT_CONT_PL S1                   |                                         $ | reduce by S -> NP_PL PRES_PERFECT_CONT_PL S1        |
# | (20) | 0 55                |  S                                               |                                         $ | accept                                              |
# +------+---------------------+--------------------------------------------------+-------------------------------------------+-----------------------------------------------------+
# +------+----------------------+-----------------------------------------+-------------------------------------+--------------------------------------+
# |      |        STACK         |                 SYMBOLS                 |                INPUT                |                ACTION                |
# +------+----------------------+-----------------------------------------+-------------------------------------+--------------------------------------+
# |  (1) | 0                    |                                         | my brother works as an accountant $ | shift                                |
# |  (2) | 0 188                |  my                                     |    brother works as an accountant $ | reduce by PRONOUN_SG -> my           |
# |  (3) | 0 116                |  PRONOUN_SG                             |    brother works as an accountant $ | shift                                |
# |  (4) | 0 116 184            |  PRONOUN_SG brother                     |            works as an accountant $ | reduce by NOUN_SG -> brother         |
# |  (5) | 0 116 59             |  PRONOUN_SG NOUN_SG                     |            works as an accountant $ | reduce by NOM_SG -> NOUN_SG          |
# |  (6) | 0 116 262            |  PRONOUN_SG NOM_SG                      |            works as an accountant $ | reduce by NP_SG -> PRONOUN_SG NOM_SG |
# |  (7) | 0 160                |  NP_SG                                  |            works as an accountant $ | shift                                |
# |  (8) | 0 160 294            |  NP_SG works                            |                  as an accountant $ | reduce by V1_SG -> works             |
# |  (9) | 0 160 286            |  NP_SG V1_SG                            |                  as an accountant $ | reduce by PRES_SG -> V1_SG           |
# | (10) | 0 160 290            |  NP_SG PRES_SG                          |                  as an accountant $ | shift                                |
# | (11) | 0 160 290 304        |  NP_SG PRES_SG as                       |                     an accountant $ | reduce by PREPOS -> as               |
# | (12) | 0 160 290 311        |  NP_SG PRES_SG PREPOS                   |                     an accountant $ | shift                                |
# | (13) | 0 160 290 311 157    |  NP_SG PRES_SG PREPOS an                |                        accountant $ | reduce by DET_SG -> an               |
# | (14) | 0 160 290 311 92     |  NP_SG PRES_SG PREPOS DET_SG            |                        accountant $ | shift                                |
# | (15) | 0 160 290 311 92 122 |  NP_SG PRES_SG PREPOS DET_SG accountant |                                   $ | reduce by NOUN_SG -> accountant      |
# | (16) | 0 160 290 311 92 59  |  NP_SG PRES_SG PREPOS DET_SG NOUN_SG    |                                   $ | reduce by NOM_SG -> NOUN_SG          |
# | (17) | 0 160 290 311 92 204 |  NP_SG PRES_SG PREPOS DET_SG NOM_SG     |                                   $ | reduce by NP_SG -> DET_SG NOM_SG     |
# | (18) | 0 160 290 311 411    |  NP_SG PRES_SG PREPOS NP_SG             |                                   $ | reduce by PP -> PREPOS NP_SG         |
# | (19) | 0 160 290 305        |  NP_SG PRES_SG PP                       |                                   $ | reduce by NP -> PP                   |
# | (20) | 0 160 290 314        |  NP_SG PRES_SG NP                       |                                   $ | reduce by S1 -> NP                   |
# | (21) | 0 160 290 406        |  NP_SG PRES_SG S1                       |                                   $ | reduce by S -> NP_SG PRES_SG S1      |
# | (22) | 0 55                 |  S                                      |                                   $ | accept                               |
# +------+----------------------+-----------------------------------------+-------------------------------------+--------------------------------------+
# +-----+-----------+-------------+--------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |             INPUT              |                     ACTION                     |
# +-----+-----------+-------------+--------------------------------+------------------------------------------------+
# | (1) | 0         |             | ajitesh had saw the accident $ | shift                                          |
# | (2) | 0 52      |  ajitesh    |         had saw the accident $ | reduce by PROPERNOUN -> ajitesh                |
# | (3) | 0 44      |  PROPERNOUN |         had saw the accident $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 160     |  NP_SG      |         had saw the accident $ | shift                                          |
# | (5) | 0 160 235 |  NP_SG had  |             saw the accident $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+--------------------------------+------------------------------------------------+
# Correction :
# Ajitesh had sawed the accident
# +------+---------------+--------------------------------+-------------------------------------------+----------------------------------------+
# |      |     STACK     |            SYMBOLS             |                   INPUT                   |                 ACTION                 |
# +------+---------------+--------------------------------+-------------------------------------------+----------------------------------------+
# |  (1) | 0             |                                | the girls were playing basketball today $ | shift                                  |
# |  (2) | 0 161         |  the                           |     girls were playing basketball today $ | reduce by DET_BOTH -> the              |
# |  (3) | 0 61          |  DET_BOTH                      |     girls were playing basketball today $ | shift                                  |
# |  (4) | 0 61 94       |  DET_BOTH girls                |           were playing basketball today $ | reduce by NOUN_PL -> girls             |
# |  (5) | 0 61 173      |  DET_BOTH NOUN_PL              |           were playing basketball today $ | reduce by NOM_PL -> NOUN_PL            |
# |  (6) | 0 61 199      |  DET_BOTH NOM_PL               |           were playing basketball today $ | reduce by NP_PL -> DET_BOTH NOM_PL     |
# |  (7) | 0 100         |  NP_PL                         |           were playing basketball today $ | shift                                  |
# |  (8) | 0 100 216     |  NP_PL were                    |                playing basketball today $ | shift                                  |
# |  (9) | 0 100 216 323 |  NP_PL were playing            |                        basketball today $ | reduce by GERUNDV -> playing           |
# | (10) | 0 100 216 367 |  NP_PL were GERUNDV            |                        basketball today $ | reduce by PAST_CONT_PL -> were GERUNDV |
# | (11) | 0 100 220     |  NP_PL PAST_CONT_PL            |                        basketball today $ | shift                                  |
# | (12) | 0 100 220 149 |  NP_PL PAST_CONT_PL basketball |                                   today $ | reduce by NOUN_SG -> basketball        |
# | (13) | 0 100 220 59  |  NP_PL PAST_CONT_PL NOUN_SG    |                                   today $ | reduce by NOM_SG -> NOUN_SG            |
# | (14) | 0 100 220 85  |  NP_PL PAST_CONT_PL NOM_SG     |                                   today $ | reduce by NP_SG -> NOM_SG              |
# | (15) | 0 100 220 312 |  NP_PL PAST_CONT_PL NP_SG      |                                   today $ | reduce by NP -> NP_SG                  |
# | (16) | 0 100 220 314 |  NP_PL PAST_CONT_PL NP         |                                   today $ | reduce by S1 -> NP                     |
# | (17) | 0 100 220 371 |  NP_PL PAST_CONT_PL S1         |                                   today $ | reduce by S -> NP_PL PAST_CONT_PL S1   |
# | (18) | 0 55          |  S                             |                                   today $ | shift                                  |
# | (19) | 0 55 83       |  S today                       |                                         $ | reduce by ADV -> today                 |
# | (20) | 0 55 194      |  S ADV                         |                                         $ | reduce by S -> S ADV                   |
# | (21) | 0 55          |  S                             |                                         $ | accept                                 |
# +------+---------------+--------------------------------+-------------------------------------------+----------------------------------------+

# %%
outputLines.append("Incorrect sentences count : {}\n\n".format(incorrectSentenceCount))
outputLines.append("---------------------------------------------\n\n")
for result in incorrectSentenceResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %%
# WRITING RESULT TO THE OUTPUT FILE

outputFile = open("output.txt", "w")
for line in outputLines:
  outputFile.write(line)
outputFile.close()
